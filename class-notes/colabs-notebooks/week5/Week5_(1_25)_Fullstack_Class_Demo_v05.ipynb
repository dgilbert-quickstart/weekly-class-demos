# %% [markdown]
# # Week 5 topic summary
#   - https://www.w3schools.com/js/
#   - javascript programming intro
#     - es1-es6+
#       - Js 1..4 - 1997-2008
#       - Es5 - 2009+
#       - Es6 - 2015+ 2020
#     - variables, if, while
#     - array
#     - object
#     - json data
#     - other
#   - dynamic programming
#   - static websites , static web pages
#     - dynamic websites ie: dynamic web pages
#     - pre- react javascript dynamic websites
#     -  event:mouse, keyboard, page, timer, DOM-Document Object-Model, code actions
#     - event attribute js script reference
#     - page script js refence
#     - external file js script refence
#   - demo dynamic web applications
#     - es1-4,es5,es6+
#     - inteactive web applications
#     - generating html using the DOM
#     - selecting DOM elements
#     - wireframe, user stories, githubpages, git clone
#     - display date/time
#     - array introduction
#     - invoice/inventory claculator
#     - contact form validation
#     - ecommerce apps
#     - todo list app or task management
#     - shopping cart application
#     - display web data app ie: json placeholder
#     - javascript games ie: canvas, tic-tac-toe, other
#     - other
#   - deply website to github pages
#   - Json document introduction demo
#   - Query REST api introduciton demo
#   - demo project #2 web application
#   - search engine demo app
#   - giphy api
#     - https://giphy.com/
#     - Giphy api introduction demo
#   - Rest API  -  Representational State Transfer API,
#     - A way for applications to communicate with each other over the interne
#     - Retrieve and update data from other websites
#     - get, post, put, delete
#     - json data
#     - promise, async/await programming
#     - non-blocking api call promise, async/await
#   - css compiler SCSS introduction
#     - css compiler SCSS introduction  demo
#   - css media queries - responsive websites
#     - css media queries - responsive websites demo
#   - other

# %% [markdown]
# # Week (1-2) - Topic summary
#   - HTML5
#   - Nav menu
#   - layout
#   - Css
#   - Bootstrap
#   - Git, Github
#   - Github pages
#   - vs.code
#     - vs.code extensions
#   - browser devtools
#   - Software Engineer Development/Tools/Management
#   - Product Development/Tools/Management

# %% [markdown]
# #Javascript demo #1
#   - https://www.w3schools.com/js/
#   - javascript programming intro
#       - es1-es6+
#       - Js 1..4 - 1997-2008
#       - Es5 - 2009+
#       - Es6 - 2015+ 2020
#     - variables, if, while
#     - array
#     - object
#     - json data
#     - other
#
# ### javascript webpage demo #1
#     - event attribute js script reference
#     - page script js refence
#     - external file js script refence
#
# <pre>
# Javascript introduciton demos
# Javascript code runs when an event occurs
# - example: mouse button click, page load event or keyboard input, timer etc
#
# -------
# Code in js file
# Code in js function
# .......
# Function - name given to a group of code
# Function parameters
# Function return
# Calling function
#
# - element events - onclick, onload, other
# - create function
# - call function
#   - display alert
#   - display log
#   - page load
#   - display text in element using DOM - Document Object Model
# - variables
#   - number, string, object
#   - cast or convert string to number
#   - Other
#
# ...........
# demo example summary #1
# ...........
#
# js script
# include js file
# javascript events
#   onclick - link click
#   onclick - button click
#   onload  - page load
# calc values, round values
# convert string to number
# string formatting, upper, lower, length, trim, other
# display date/time
# get text from input field
#   - placeholder, name, id, required
#   - onclick
# function with parameters
# other
#
# ...........
# demo example summary #2
# ...........
# DOM Intro
# - select document elements
# - display information in document
# - other
#
# ...........
# demo example summary #3
# ...........
# - arrays, loops
# - contact form validation
# - timer event start/stop
#
# </pre>

# %% [markdown]
# #Javascript invoice/Inventory calculator demo webpage #1
# - https://www.w3schools.com/js/
#
# <pre>
# Demo #1
# -----------------------
# - calculate two invoice items
# - other
#
# Demo #2
# -----------------------
# - calculate five invoice items
# - other
#
# Demo #3
# -----------------------
# - calculate ten invoice items
# - other
#
# </pre>

# %% [markdown]
# #Javascript form validation demo website #
#   - https://www.w3schools.com/js/
#
# <pre>
# Demo #1
# --------------------
# - validate first name
# - validate last name
#
# Demo #2
# --------------------
# - validate first name
# - no validation for last name
# - validate email
# - validate comment
#
# </pre>

# %% [markdown]
# #Introduction to Javascript Arrays demo #1
#
# <pre>
#
# array demo
# ------------------
# - calculate inventory/invoice of 20 items
# - loops, for, while
#
# </pre>

# %% [markdown]
# #Introduction to Javascript date/time object
#   - https://www.w3schools.com/js/

# %% [markdown]
# #Javascrpt demo #2
#   - https://www.w3schools.com/js/
#
#   - dynamic programming
#   - inteactive web applications
#   - static websites , static web pages
#   - dynamic websites ie: dynamic web pages
#     - pre- react javascript dynamic websites
#     -  event:mouse, keyboard, page, timer, DOM-Document Object-Model, code
#
# ---
#
#   - demo dynamic web applications
#     - wireframe, user stories, githubpages, git clone
#     - es6
#     - generating html using the DOM
#     - selecting DOM elements
#     - display date/time
#     - invoice claculator
#     - contact form validation
#     - array introduction
#     - shopping cart application
#     - display web data app ie: json placeholder
#     - non-blocking api call promise, async/await

# %% [markdown]
# #Json document introduction demo
# #Query api introduciton demo
# #Giphy api introduction demo
#
# #google fonts intro demo
#   - https://www.w3schools.com/css/css_font_google.asp
#
# #css compiler SCSS introduction  demo
#   - https://www.w3schools.com/sass/
#
#   - scss generates - style1.css
#   - link to href="/css/style1.css"
#
#   - ues to build large nuber of css code
#   - add css and or scss code
#   - scss re-use css code ie: functions in javascript
#   - create variables
#   - create functions
#   - scss also generates backword compatable css code
#   - other
#
#
# #css media queries - responsive websites demo
#   - display flex
#   - https://www.w3schools.com/css/css3_flexbox.asp
#   - media queries
#   - https://www.w3schools.com/css/css_rwd_mediaqueries.asp

# %% [markdown]
# #Html Javascript DOM demo website Page 2
# - dyamic interactive javascript webpage
# - DOM demo wireframe
#
# #user stories demo
# - use stories example (who,what,why)
# - as a user, select search button, display image search results
# - user, select clear button to clear the search text field
#
# #### user stories ad verified by quality assurance (QA) team
# #### user stories are sometimes created by QA team and developers
# #### development can also include other requirements in addition to user stories. err fix, additional requirenmts
# #### user stries and requiremts are enterd in a project management QA tool call ed Jira or other tools
# #### daily, weekly meeting with developers and QA team to discuss requirement timeline called Scrum meetings
# ### each requirement has a unique id
#
# # Additional requirement, feature
# - example: add style to page
#
# <pre>
#
# DOM demo wireframe
# ------------------------
#
# [logo] page1 page2 page3
#
# Page 2 - dom demo
#
# ------------  [search]  clear
#
# lin1 link2 link2
#
# [div display info]
#
# </pre>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Javasript DOM introduction
# - w3schools.com/javasscript
# - dom
#
# <pre>
# Dynamic website development - Dynamically updating parts of the web page without refreshing the entire webpage. The entire webpage is not reloaded. Only some of the webpage is updated.
# Technologies used to create dynamic websites. Javascript DOM, Single Page Application (SPA)  development ie: Ract, Angular, Vue, Other.
# Some websites can be dynamic ie: 80%-90% dynamic - 10-20% static content, 30% dynamic, 70% static etc..
#
# </pre>

# %% [markdown]
# # search screen javascipt DOM demo #software development requirements
# - build html from wireframe
# - create user stories
#
# - create search function ie: btnSearch
#   - select text field and display div using document.getElementById
#   - validate if text field and display div is not null, if so and exit function
#   - validate if text field is empty, if so exit function
#   - display search text in display div
#
# - create clear function  ie: lnkClear
#   - select text field and display div using document.getElementById
#     - validate if text field and display div is not null, if so and exit function
#     - clear text field
#     - set keyboard focus to the text field

# %% [markdown]
# # contact us javascipt DOM demo #1
# - build html from wireframe
# - create user stories
# - create page3.js file
# - create functions ie: btnSubmit, lnkClear in page3.js file
# - add id to each field, ie: txtfirstname, txtlastname, txtemail, txtcomment
# - add div display info id - divdisplayinfo
# - add onclick event function reference: onclick="btnSubmit", onclick="lnkClear"
#
# <pre>
# [logo] page1 page2 page3
#
# Page3 - Contact Us
#
# [divdisplayinfo]
#
# * first name ---------------
# last name ---------------
# * email ---------------
# * comment ---------------
#
# [submit] clear
#
# </pre>

# %% [markdown]
# #page3 - constact us form validation requirements
#
# - undefined = field is not defined/created
#   - if(txtfirstname1 == null)
#   - referencing a variable that was never defined
#
# - null = field is defined/created but does not have a value
#   - var txtfirstname;
#
# - validation example:
#   - if (txtfirstname == null | txtfirstname == undefined)
#
# <pre>
# <xmp>
# function btnSubmit requirements
#
# div-display-info:
#   1- select div-display-info using document.getElementById
#   2- validate if div-display-info is not null or undefined, if so, display element not found message and exit function
#
# firtname:
#   1- select firstname field using document.getElementById
#   2- validate if firstname field is not null or undefined, if so, display field not found message and exit function
#   3- validate if firstname field is empty, if so, display invalid field entry message and exit function
#
# lastname:
#   1- select lastname field using document.getElementById
#   2- validate if lastname field is not null or undefined, if so, display invalid field entry message and exit function
#
# email:
#   1- select email field using document.getElementById
#   2- validate if email field is not null or undefined, if so, display field not found message and exit function
#   3- validate if email field is empty, if so, display invalid field entry message and exit function
#
# comment:
#   1- select comment field using document.getElementById
#   2- validate if comment field is not null or undefined, if so, display field not found message and exit function
#   3- validate if comment field is empty, if so, display invalid field entry message and exit function
#
# - display form field information in log ie:
#
# msgText = "form submitted: firstname: " + txtfirstname.value + ", lastname: " +
# txtlastname.value + ", email: " + txtemail.value + ", comment: ";
#
# console.log(msgText)
#
# divdisplayinfo.innerText = "form submitted"
#
# - clear each field value
# txtfirstname.value = "";
# txtlastname.value = "";
# txtemail.value = "";
# txtcomment.value = "";
#
# txtfirstname.focus();
# </xmp>
# </pre>

# %% [markdown]
# ### optimize, refromatting, refactoring, reusing code
#
# ### best practice: add minimal if statements and error code at first
#   - add other code as required
#
# <pre>
#
# formSubmit() {
#
#   validate_firstname()
#   validate_emil()
#
#   if validate lastname
#        //show/hide error labels
#
#   if validate comment
#
# }
#
# //---------------------------------
#
# function validate_firstname() {
#   //validate firstname
#   if
#   //show/hide error labels
# }
#
# function validate_emil() {
#   //validate email
#   if
#   //show/hide error labels
#
# }
# </pre>

# %% [markdown]
# #Array intro
#   - store a sequence of data in memory
#   - reference: w3schools array introduction
#   - loop through item in array
#   - access array index
#   - add, update and delete array items
#   - array can contain any valid data types and combined data types
#     - array1 = [1,2,3,10,73,1]
#     - array2 = ["one","two","three","two"]
#     - array3 = [1,"one",2,"two","three","two", true]
#
# # Type of Apps using arrays
# # shopping cart, invoice, inventory total
# # todo list app, app to strore a list of items
# # Demo array problem
# - 1. compute a list of 5 items
# - 2. compute a list of 100+ items
#
# #non array example
# - compute 5 items
#
# <pre>
#
# const item1 = 5
# const item2 = 10
# const item3 = 15.1
# const item4 = 20
# const item5 = 25
#
# const total = (item1 + item2 + item3 + item4 + item5)
#
# console.log("total: ", total)
# console.log(`total: , ${total}`)
#
# //rount floating point number , ie: 2 decimal points
# console.log(`round total: , ${total.toFixed(2)}`)
#
# </pre>
#
# #array example #1
# <pre>
#
# const items = [5,10,15.1,20,25]
# const item_names = ["iteama","iteamb","iteamc","iteamd","iteame",]
# const item_names_and_values = [5,"iteama",15,"iteamb",15.1,"iteamc","iteamd","iteame",]
#
# /*
# --- array index start at 0 = 1st item, ...
# --column index = 0...1..2
# --or
# -- index = row starting at 0
#
# 0 = 5
# 1 = 10
# 2 = 15.1
# 3 = 20
# 4 = 25
#
# */
#
# //access element index starting at index 0
# //#-- index not found or index out of bound
# //#-- access and index not in range ie: -1, 5, ... 10 ..
# const total = (items[0] + items[1] + items[2] + items[3] + items[4])
#
# console.log(`total: , ${total}`)
#
# //rount floating point number , ie: 2 decimal points
# console.log(`round total: , ${total.toFixed(2)}`)
#
# //access item index
# console.log(item_names[0], item_names_and_values[2])
# </pre>
#
# #array loop example #1
# <pre>
# <xmp>
# const items = [5,10,15.1,20,25]
#
# console.log("array length: ", items.length);
#
#
# let total = 0;
#
# //for loop is used to loop through a fixed number of items
# //for loop - uses a counter i , incremented for each loop
# //counter start loop
# //loop stop when counter is > then items.length
#
# //for(counter/start=0;loop stop condition;increase/decrease counter)
#
# //i = i + 1
# //or
# //i++
# //or
# //i--
#
# //-
# //- start at i = 0; loop while i < array.lngth; count i each time through loop
# //- can have endless/infinate or out of memory loop
# //-
#
# for(i=0;i<items.length;i++) {
#
#   //total = total + current item[index]
#   //or any valid javascript code
#
#   //total = total + items[i]
#
#   total += items[i]
#   console.log("* i = ", i)
# }
#
# console.log(`total: , ${total}`)
#
# //rount floating point number , ie: 2 decimal points
# console.log(`round total: , ${total.toFixed(2)}`)
#
# </xmp>
# </pre>

# %% [markdown]
# #array for loop demo #2
#
# <pre>
# <xmp>
#
# ##########################
#
# <a href="#" onclick="totalitems()">demo total</a>
#
# ###########################
#
# function totalitems()
# {
#
#    let = msgText = "#page1 : totalitems"
#    console.log(msgText);
#
#    items = [1,2,3,4,2,5]
#    items2 = [1,"two",3,"four",2,5]
#
#    total = 0
#    total2 = 0
#
#    for(cntr=0; cntr<items.length;cntr++)
#    {
#        //total = total + items[cntr]
#        total += items[cntr]
#
# 	  /*
#          if (typeof items2[cntr] == "int")
#          {
#            total2 += items2[cntr]
#          }
#      */
#
#    }
#
# }
#
# </xmp>
# </pre>

# %% [markdown]
# #Other array features array add,update,delete  search, loop, sort, other
# - other loops, do loop, while loop , foreach
# - wschools javascript array
# - https://www.w3schools.com/js/default.asp
# - javascript array and other exercises
#   - https://www.w3schools.com/js/js_examples.asp
#   - https://www.w3schools.com/js/js_exercises.asp
#
# <pre>
# <xmp>
#
# function lnkArrayAddRemoveLoopDemo1()
# {
#     let msgText = "# page1 : lnkArrayAddRemoveLoopDemo1"
#     console.log(msgText.toUpperCase())
#
#     const items = [5,10,15.1,20,25]
#     const item_names = ["iteama","iteamb","iteamc","iteamd","iteame",]
#     const item_names_and_values = [5,"iteama",15,"iteamb",15.1,"iteamc","iteamd","iteame",]
#
#     //print arrays
#     console.log("---- arrays ---------")
#     console.log(items)
#
#     console.log("-------------")
#     console.log(item_names)
#
#     console.log("-------------")
#     console.log(item_names_and_values)
#
#     console.log("-------------")
#     console.log("")
#
#     //array length
#     console.log("---array--length----")
#     console.log(items.length)
#     console.log(item_names.length)
#     console.log(item_names_and_values.length)
#     console.log("")
#
#     //access array by index
#     console.log("-- access array index ")
#     console.log(items[0])
#     console.log(item_names[1])
#
#     let index = 1
#     console.log(item_names_and_values[index])
#
#     console.log("-- increase index index++ = add 1")
#
#     index++
#     console.log(item_names_and_values[index])
#
#     console.log("")
#     console.log("--add item---")
#
#     //add item to array
#     items.push(20.7)
#     //items.push //any data type - string, number, boolean, object
#
#     //print array
#     console.log(items)
#
#     console.log("")
#
#     console.log("--- remove item ---")
#     //remove item from array
#     items.pop() //remove element from end of array
#
#     //remove element at an index
#     //items.splice(1,1) //splice(index, number_of_item_to_remove)
#
#     //print array
#     console.log(items)
#     console.log("")
#
#     //update at array index
#     items[2] = 53.72
#
#     //print array
#     console.log(items)
#     console.log("")
#
#     console.log("---- array loop ----")
#
#     //array loop
#     for(ndx=0;ndx<items.length;ndx++){
#         console.log(`${ndx} - ${items[ndx]}`)
#     }
#
#     console.log("")
#
#     //other loop do loop, while loop , foreach
# }
#
#
# </xmp>
# </pre>

# %% [markdown]
# #nested arrays demo
#
# <pre>
# <xmp>
#
# //tesing - can write js code in browser dev tools
# //browser dev tools - can not copy code to browser deve tools
#
# //nested arrays
# const items = [1,2,3,["a","b"],5]
#
# consoel.log(items)
# console.log(items.length)
# console.log(items[3].length)
#
# //nested loops
#
# for(index=0;index<items1.length;index++)
# {
#     if (items[index] typeof array) {
#
#        //re-use index variable scope
#        //for(index=0;index<items[index].length;i++)
#        //variable scope reference logical error
#        //best practice : use different variables
#
#        for(i=0;i<items[index].length;i++)
#        {
#              console.log(`${items[index][i]}`)
#        }
#    }
# }
#
# </xmp>
# </pre>

# %% [markdown]
# # api data get summary demo #1
# *use browser dev tools to preview api request/response *
#
# <pre>
# <xmp>
#
# example:
#  single request
# 	 request api data from website
# 	 website return api data
#
#  multiple api request
# 	 request api data from website
# 	 website return api data
# 	 website return api data
# 	 website return api data
#
#
#  multiple api request
# 	 request api data from website
# 	 request api data from website
# 		 website return api data
# 	 request api data from website
# 	 website return api data
# 	 website return api data
#
#
# erors
# - timeout when sending, receiveing request
#
# api request demo websites , low to high api requests
# - websites with ads
# - streaming websites
# - gaming websites
# - other
#
# https://www.w3schools.com/js/default.asp
# - previeww api request using browser devtools network tab
# - filter fetch xhr
# - preview data returned and where data is stored ie: localstorage
#
#
#
# #################################################
#
# api data returned example #1
#
# result1
#    [ ..... ]
#
# result2 - nested result
#    [ ...[..].. ]
#
# result2 - deeply nested result
#    [ ...[..]..[]... ]
#
#
# * best practice: return nested data in 1 request instead of multiple request/response, requires less api calls
#
# * nested loops to display nested data returned
#  - for
#    - for
#
#
# </xmp>
# </pre>

# %% [markdown]
# #Javascipt API Summary
#
# <pre>
# <xmp>
# REST API, or Representational State Transfer Application Programming Interface,
# is a type of API that uses HTTP requests to allow applications to communicate
# with each other. REST APIs are often used in web and mobile app development.
#
# common http verbs used to maintain data from another ewebsite
#   - GET - retrieve data
#   - POST - send data
#   - PUT - update data
#   - DELETE - delete data
#
# API Data format
#   - Json - Javascript Object Notation ie: NOSQL
#     - combines javascript data types and arrays
#     - ie: {id, name}
#     - ie: [{id, name}, {id, name}]
#     - ie: [{id, name, ["a","b"]}, {id, name}]
#     - data values can be null or not present
#     - ie: [{id, name}, {id}]
#   - {key:, value:}
#   - example: {id:1, name:"item1"}
#   - nested json data
#   - example: [{id:1, name:"item1",["item1","item2"]}]
#
# Technologies using json document
# - mongodb , other
#
# - Other data format
#   - xml, text, binary ie: images, video
#
# </xmp>
# </pre>
#
# # Browser libraries used to manage Api data form another website
#  *Preview api - Browser Devtools - Network*
# `
# - Ajax -
#   - https://www.w3schools.com/Js/js_ajax_intro.asp
#   - legacy way to manage api data from another website
#   - flexable, intermediate code
#   - does not support promise, async/await
#   - custom code to implement promise, async/await
#
# - Jquery
#   - https://www.w3schools.com/jquery/
#   - legacy plugin ( via url reference), way to manage api data from another website
#   - flexable, minimal code
#   - does not support promise, async/await
#   - custom code to implement promise, async/await
#
# - Fetch
#   - https://www.w3schools.com/js/js_api_fetch.asp
#   - https://medium.com/@turingvang/fetch-api-example-86ddf525fa69
#   - modern library manage api data from another website
#   - supported by all browsers ie: es5+ - 2014+
#   - flexable, minimal code
#   - supports, promise, async/await
#
# *Other api libraries,  axios*
#
# #Mobile applications use api for send/receive, update data
#
# #Api producer websites
#
# - produce api data
#   - get, post, put, delete
#   - most websites has an api producer feature
#   - json data returned is determined by the porducer website
#   - documnets which describes and provides examples of json api data
#   - require signup and apikey to get, post, update, delete
#   - used for product/website data integration
#
#   - producer api website example:
#     - jssonplaceholder.org -> get, test: post, put, delete
#     - giphy.com -> get
#     - many api producer website
#     - ie: facebook, amazon, google, other
#     - sports, gmail
#
# - Create your own custom producer api using technologies nodejs/express, python, other
#
# - consumer websites
#   - any website ca consume api
#   - get, post, put, delet

# %% [markdown]
# # Json object introduction
# - https://www.w3schools.com/js/js_json.asp
# - https://www.w3schools.com/js/js_json_intro.asp
#
# ### Json documents are usually consume/retrieve as readonly
#   - can update json douments
#   - custom development to update json documents
#   - or use mongodb, postgresql or other json systems
#
# ### Json document ie: NOSQL , or table and rows in a daatabase
# - example:
# - array [] rows
# - {} 1 row of columns or fields
# - Root or starting element can be a [] or {}
#
# ### Users json document example ie: contact us or register data
#
# <pre>
# -1 document
# {"id":1,"name":"ann","email":"ann@gmail.com"}
#
# -or-
# - multiple documents
# [
# {"id":1,"name":"ann","email":"ann@gmail.com"},
# {"id":2,"name":"sam","email":"sam@yahoo.com"}
# ]
#
# -or- sami-structured document - null or missing data
# - custom code to validate null and missing data
# [
# {"id":1,"email":"ann@gmail.com"},
# {"id":2,"name":"sam","email":null}
# ]
#
# -or- nested document example 1##
# [
# {"id":1,"name":"ann","email":"ann@gmail.com","address":[""street":"...","city":"..."]},
# {"id":2,"name":"sam","email":"sam@yahoo.com"}
# ]
#
# -or- nested document example 2##
# [
# {"id":1,"name":"ann","email":"ann@gmail.com","address":[""street":"...","city":"..."]},
# {"id":2,"name":"sam","email":"sam@yahoo.com","address":{"street":"..."}}
# ]
#
# -- access fields/keys/elements in a json document
#
# example #1
# const user = {"id":1,"name":"ann","email":"ann@gmail.com"}
#
# console.log(user.name)
#
# //display json data as tring
# console.log(JSON.stringify(user))
#
# example #2
#
# users = [
# {"id":1,"name":"ann","email":"ann@gmail.com"},
# {"id":2,"name":"sam","email":"sam@yahoo.com"}
# ]
#
# //display json data as tring
# console.log(JSON.stringify(users))
#
# console.log(users[0].id)
# console.log(users[0].name)
# console.log(users[1].id)
# console.log(users[1].name)
#
# --- for loop
#
# --- json document errors: null, missing data, incomplete - [], {}, fields, “” commas,
#
#
#
#
# </pre>
#
# API Data format
#   - Json - Javascript Object Notation ie: NOSQL
#   - combines javascript data types and arrays
#   - access json object array/rows []
#   - json object {field/keys/columns,fields/keys/columns}
#   - {key:, value: data type}
#   - fields/keys/columns: data type - string, int, float, object, array, other
#   - example: {id:1, name:"item1"}
#   - valid, invalid json documents
#     - array json documents []
#     - object json documents {}
#     - document error: {id name:}
#     - document error: {id, name:
#     - document error: {"id":, "name:}
#     - nested array, object json documents
#     - example: [{},{}]
#     - example: {[],[]}
#     - data values can be null or not present
#     - ie: [{id, name}, {id}]
#   - parsing json document,
#     - json string to object
#     - json object to string
#   - json object fields
#    - example: {id, name:}
#   - nested json documents
#   - loop through json document ie: loop
#   - nest documents - nested loops
#
# API Data format
#   - Json - Javascript Object Notation ie: NOSQL
#     - combines javascript data types and arrays
#     - ie: {id, name}
#     - ie: [{id, name}, {id, name}]
#     - ie: [{id, name, ["a","b"]}, {id, name}]
#     - data values can be null or not present
#     - ie: [{id, name}, {id}]
#   - {key:, value:}
#   - example: {id:1, name:"item1"}
#   - nested json data
#   - example: [{id:1, name:"item1",["item1","item2"]}]
#
# ### custom development to validate and retrieve json data
# ### also may require nested loops
#
# # example json document files
#   - comments, posts, users
#   - giphy result document
#
# # example api website
# - https://www.jsonplaceholder.org/

# %% [markdown]
# #Giphy website
#   - https://giphy.com/
#   - signup , select api option
#
# ## can also test calling giphy from the browser
# - https://api.giphy.com/v1/gifs/search?api_key=..........&q=cars
#
# ##create a new api key - developer / dashboard  - your api key
#   - https://developers.giphy.com/
#   - select create new api key
#   - enter a app name and description
#   - select web
#   - select generate/create api key
#
# ##preview api
#     - https://developers.giphy.com/
#     - your api key
#     - or Ready to create another API Key
#
# ## Error create a new Api key
#   - error - Partner Hub operates in read-only mode
#   - exit all giphy browser tabs
#   - clear browser cache 24 hours
#
#
# #demo get gpihy apikey and access giphy api data
#   - https://giphy.com/
#   - https://developers.giphy.com/
#   - https://developers.giphy.com/explorer/
#
# <pre>
# <xmp>
# https://support.giphy.com/hc/en-us/articles/360020283431-Request-A-GIPHY-API-Key
#
# Request A GIPHY API Key
# Interested in requesting a GIPHY API key for your app? Visit our developer portal here, click Create An App,
#
# </xmp>
# </pre>
#
# <pre>
# <xmp>
# Choose an app / API Key
# default dashboard: .....api.key.....
#
# Choose a resource
# default
# GIPHY PUBLIC API
#
# Choose an endpoint
# search
#
# Request URL
#
# https://api.giphy.com/v1/gifs/search?api_key=..........&q=cars
#
# or
#
# https://api.giphy.com/v1/gifs/search?api_key=..........&q=cars&limit=25
#
# or
#
# https://api.giphy.com/v1/gifs/search?api_key=..........&q=cars&limit=25&rating=g
#
# or
#
# https://api.giphy.com/v1/gifs/search?api_key=..........&q=cars&limit=25&offset=0&rating=g&lang=en&bundle=messaging_non_clips
#
# Result data
# ... json document ...
#
# </xmp>
# </pre>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #callback functions or ananymous functions - week 7-8-9
#   - learn more from w3school.com
#   - function getdata(data, statue) -- developer call function
# - some function use callback/ananymous function -- javascript calls callback
# ananymous
#
# <pre>
# <xamp>
#
# //callback functions or ananymous functions - week 7-8-9
# //learn more from w3school.com
# //example:
# // function getdata(data, statue) -- developer call function
# // or
# // callback or ananyomous
# // some function use callback/ananymous function -- javascript calls callback/ananymous
# // -- when the data is available javascript call the callback/ananymnous function
# //
# //function my_callback_function(data, status)
# //{
# //}
# //
# //$.get(_api_url_endpoint_users, my_callback_function)
# //
# //$.getJSON(_api_url_endpoint_users, function(data, status)
# </xmp>
# </pre>

# %% [markdown]
# # promise, async/await programming introduciion
# - Learn more at W3schools
#
# # browser devetools - simulate network traffic and offline
#   - from browser dev tools - select network
#   - throttle network ie: 3g, 46, offline
#
# <pre>
# <xmp>
#
# some javasccript functions use
# callback <- called by js, or developer
# - ie: nested callback can be complex
#
# parameter in function
#
# $.get(praram1,function(){})
#
#
# -------------------------
# promise
# -------------------------
#
# modern js uses instead of callback
# js promise - non blocking code
# nested function chanining
# - ie: nested callback can be complex
#
# %.get().then()
# {
# }
# .then()
# {
# }
# .then()
# {
# }
# .error()
# {
# }
#
# -------------------------
# async/await
# -------------------------
#
# async = define non blocking function
# await - wait until data is avaliable
#
# code can continue until awaited data is available
#
# async getdata()
# {
#   result = await %.get()
# }
#
#
#
# </xmp>
# </pre>

# %%
# %%html
# <style>
#   .global-center-page {
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
# }
#
# .global-footer {
#     text-align: center;
# }
#
#
# .div-scroll-1 {
#     width: 400px;
# }
#
#
# .div-scroll-2 {
#     border: 1px solid #000000;
#     width: 400px;
#     height: 200px;
#     word-wrap: break-word;
#     overflow-x: hidden;
#     overflow-y: auto;
# }
#
# /*
# media query - adjust screen based on screen width or height
# */
#
# /*
# add google font
# */
#
# /*
# add scss - css compiler
# */
#
# </style>

# %%
# %%html
# <pre>
# <xmp>
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Page5 - Giphy API Search</title>
#     <link rel="stylesheet" href="css/global-1.css">
#     <script src="js/page5.js"></script>
# </head>
# <body onload="page_load()">
#     <nav>
#         <a href="index.html"><img src="logo-1.png" width="100" height="30" alt="logo-1"></a>
#         <a href="page1.html">page 1 - Array Intro</a>
#         <a href="page2.html">page 2 - Json intro</a>
#         <a href="page3.html">page 3 - Json Api Intro</a>
#         <a href="page4.html">page 4 - Giphy Api Intro</a>
#         <a href="page5.html">page 5 - Giphy Api search</a>
#     </nav>
#     <P></P>
#     <main class="global-center-page">
#         <header>
#             <h2>
#                 Page4 - Giphy API Search
#             </h2>
#         </header>
#         <p></p>
#             <div>
#                 <input type="text" id="txtsearch" placeholder="# enter text to search" maxlength="25">
#                 <button onclick="btnSearch()">search</button>
#                 <a href="#" onclick="lnkClear()">clear</a>
#             </div>
#         <p></p>
#         <div id="divdisplayinfo" class="div-scroll-1">
#         </div>
#         <p></p>
#         <div>
#             <a href="#" onclick="giphyApiDemo1()">Giphy Api demo 1</a><br>
#         </div>
#         <p></p>
#     </main>
#     <p></p>
#     <footer class="global-footer">
#         footer @ 2025
#     </footer>
# </body>
# </html>
# </xmp>
# </pre>

# %%
# %%javascript
#
# function page_load(){
#
#     const msgText = "# page4: page load"
#
#     console.log(msgText.toUpperCase())
# }
#
#
# function giphyApiDemo1()
# {
#
#     let msgText = "# page4: giphyApiDemo1"
#
#     console.log(msgText.toUpperCase())
#
#     const divdisplayinfo = document.getElementById("divdisplayinfo");
#
#     if (divdisplayinfo == null | divdisplayinfo == undefined){
#         msgText = "## Page3 - divdisplayinfo not found"
#         console.log(msgText)
#         return false;
#     }
#
#     divdisplayinfo.innerText = msgText;
#
#     //giphy url and api key
#
#     const _search_text = "cars" //input text fields
#     const _giphy_ApiKey = ""
#     const _giphy_result_data_file = "./data/giphy2.json";
#     const _giphyApi_Url = `https://api.giphy.com/v1/gifs/search?api_key=${_giphy_ApiKey}&q=${_search_text}&limit=25&rating=g`;
#
#     //fetch - then - promise - non-blocking - javascript call then when data is available
#     //another way of implementing promise = async/await
#
#     //inline or 1 line if statement
#     let _request_url = (_giphy_ApiKey.trim().length == 0)? _giphy_result_data_file : _giphyApi_Url;
#
#     console.log("---- _request_url---- ");
#     console.log(_request_url)
#     console.log("")
#
#     fetch(_request_url)
#     .then(response => {
#       if (!response.ok) {
#         //throw/raise - generate or a error and descrption
#         throw new Error('Network response was not ok');
#       }
#       //-- convert data from text to json
#       return response.json();
#     })
#     .then(data => {
#
#         console.log("#### giphy fetch.promise then - post data ###")
#         console.log(data);
#
#         console.log("")
#         console.log("-------- giphy json data as string ----")
#         //console.log(JSON.stringify(data))
#         console.log("")
#
#         const _image = data.data[0].images.original.url;
#
#         console.log("-- image ---");
#         console.log(_image)
#         console.log("")
#
#         //retrieve giphy data
#         const giphapi_image = `<img width='200' height='150' src='${_image}'>`
#
#         divdisplayinfo.innerHTML = giphapi_image
#
#     })
#     .catch(error => {
#       console.error('## There was a problem with the fetch operation:', error);
#       divdisplayinfo.innerText = error;
#     });
#
#     console.log("..continue fetching gphy data...demo of non-blocking code")
#     divdisplayinfo.innerText = "..continue fetching giphy data...demo of non-blocking code";
#
#
#     //verify root or starting element can be a [] or {}
#
#     //verify invalid, valid document
#
#     //retieve nested json document fields
#
#     //loop through json documents , nested loops
#
#     //verify element level or starting element can be a [] or {}
#
#     //retiieve nested json document fields or array fields reference
#
#     //verify element level or starting element can be a [] or {}
#
#     //convert json string to json object
#
# }
#
#
# function btnSearch(){
#
#   let msgText = "# page5: btnSearch" //string
#   console.log(msgText.toUpperCase());
#
#   //select text field and display div using document.getElementById
#   const txtsearch = document.getElementById("txtsearch"); //HTMLElement or null
#   const divdisplayinfo = document.getElementById("divdisplayinfo"); //HTMLElement or null
#
#   //validate if text field and display div is not null, if so and exit function
#   if(txtsearch == null){
#       msgText = "# txtsearch field not found"
#       console.log(msgText)
#       return false //stop onclick and exit function
#   }
#
#   if(divdisplayinfo == null){
#       msgText = "# divdisplayinfo field not found"
#       console.log(msgText)
#       return false //stop onclick and exit function
#   }
#
#   //######## other if condition examples ####
#   //if(txtsearch != null) -> not null
#   //if(txtsearch == null ! divdisplayinfo == null)  -> or
#   //if(txtsearch == null & divdisplayinfo == null) -> or
#
#   //validate if text field is empty, if so exit function
#   if(txtsearch.value.trim().length == 0) {
#       msgText = "# please enter a valid search text"
#       console.log(msgText)
#       divdisplayinfo.innerText = msgText
#       return false //stop onclick and exit function
#   }
#
#   //display search text in display div
#   msgText = "# searching for: " + txtsearch.value
#
#   //divdisplayinfo.innerHTML = "<br>" + msgText + "</b>"
#   divdisplayinfo.innerText = msgText;
#
#   //--- Giphy Api Search code ------
#
#       //giphy url and api key
#
#       const _search_text = txtsearch.value //input text fields
#       const _giphy_ApiKey = ""
#       const _giphy_result_data_file = "./data/giphy2.json";
#       const _giphyApi_Url = `https://api.giphy.com/v1/gifs/search?api_key=${_giphy_ApiKey}&q=${_search_text}&limit=25&rating=g`;
#
#       //fetch - then - promise - non-blocking - javascript call then when data is available
#       //another way of implementing promise = async/await
#
#       /*
#         let _request_url = ""
#
#         if(_giphy_ApiKey.trim().length == 0) {
#         _request_url = _giphy_result_data_file
#         }
#         else
#         {
#         _request_url = _giphyApi_Url;
#         }
#
#         also: optional: optimization, code refactoring, update a variable in condenced statement
#         similar to ? :
#         used whith nested code/nested updates
#
#         ?? -- chek if variable is null else use variable
#         || -- chek if variable is null else use variable
#         && -- chek if variable is null else use variable
#
#         */
#
#       //inline or 1 line if statement
#       let _request_url = (_giphy_ApiKey.trim().length == 0)? _giphy_result_data_file : _giphyApi_Url;
#
#       console.log("---- _request_url---- ");
#       console.log(_request_url)
#       console.log("")
#
#       fetch(_request_url)
#       .then(response => {
#         if (!response.ok) {
#           //throw/raise - generate or a error and descrption
#           throw new Error('Network response was not ok');
#         }
#         //-- convert data from text to json
#         return response.json();
#       })
#       .then(data => {
#
#           console.log("#### giphy fetch.promise then - post data ###")
#           console.log(data);
#
#           console.log("")
#           console.log("-------- giphy json data as string ----")
#           //console.log(JSON.stringify(data))
#           console.log("")
#
#           let _image = "";
#
#           if(data == null | data.data.length == 0){
#             divdisplayinfo.innerText = "# no results found"
#             return false;
#           }
#
#           _image = data.data[0].images.original.url;
#
#           console.log("-- first image ---");
#           console.log(_image)
#           console.log("")
#
#           //retrieve giphy data
#           //const giphapi_image = `<img width='200' height='150' src='${_image}'>`
#
#           //display multiple images
#           //build dynamic html in string or using DOM to dynamically append html elements
#
#           //add css style
#           let _html = "<div>"
#
#           for(i=0;i<data.data.length;i++)
#           {
#             //unit test: display 5 images , exit loop
#             if(i>5)
#             {
#               //ext loop
#               break;
#             }
#
#             _image = data.data[i].images.original.url;
#             _html += `<img width='100' height='100' src='${_image}'>`
#             //display 3 images per row
#           }
#
#           _html += "</div>"
#
#           console.log("-------------- html string ----------")
#           console.log(_html)
#           console.log("")
#
#           divdisplayinfo.innerHTML = _html
#
#       })
#       .catch(error => {
#         console.error('## There was a problem with the fetch operation:', error);
#         divdisplayinfo.innerText = error;
#       });
#
#       console.log("..continue fetching gphy data...demo of non-blocking code")
#       divdisplayinfo.innerText = "..continue fetching giphy data...demo of non-blocking code";
#
#
#   //--- Giphy Api Search code ------
#
#   //txtsearch.value = ""; //clear text field
#   txtsearch.focus(); //move keyboard cursor to text field
#
# }
#
# function lnkClear(){
#
#   let msgText = "# page5: lnkClear"
#   console.log(msgText.toUpperCase());
#
#   //select text field and display div using document.getElementById
#
#   //const txtsearch = document.getElementById("txtSearch"); //HTMLElement or null
#   const txtsearch = document.getElementById("txtsearch");  //HTMLElement or null
#   const divdisplayinfo = document.getElementById("divdisplayinfo");  //HTMLElement or null
#
#   //validate if text field and display div is null, if so and exit function
#   //-- undefined = field was not definded or created
#   //-- null - field was defined and does not have a value
#   //-- undefined variable is a variable that was not ceeated
#
#   //const var1; //null variable - defined but does not have any value
#
#   //if(txtsearch == null | txtsearch1 == undefined) {
#   if(txtsearch == null | txtsearch == undefined) {
#       msgText = "# txtsearch is null"
#       return false;
#   }
#
#   txtsearch.value = ""; //clear text field
#   txtsearch.focus(); //set keyboard focus to the text field
#
#   //divdisplayinfo.innerText = ""; //clear div content
#
# }

# %% [markdown]
# #create Giphy Api search engine demo app
# - create public repo
#   - repo name: GiphyApiSearchV1
#   - https://github.com/dgilbert-quickstart/GiphyApiSearchV1.git
# - deplpoy app to github pages
#   - https://dgilbert-quickstart.github.io/GiphyApiSearchV1/
# - clone repository
#   - command teminal
#   - git clone github url
#     - git clone https://github.com/dgilbert-quickstart/GiphyApiSearchV1.git
#     - cd into cloned directory
#     - cd GiphyApiSearchV1
# - update website locally
# - preview website locally
#   - vs.code live server
# - push changes to github repo
# - in cloned directory ie: GiphyApiSearchV1
# - git add, commit, push
# - optionaL git log, status, pull

# %% [markdown]
# <pre>
# <xmp>
# /*
#
# https://www.w3schools.com/sass/
#
# scss generates - style1.css
#
# <link to href="/css/style1.css">
#
# - ues to build large nuber of css code
# - add css and or scss code
# - scss re-use css code ie: functions in javascript
# - create variables
# - create functions
# - scss also generates backword compatable css code
# - other
#
# */
#
# /*
# variables
# */
#
# $bgcolor: lightblue;
# $textcolor: darkblue;
# $fontsize: 18px;
#
# .h1-style-2 {
#     color: $textcolor
# }
#
# /*
#
# scss to genrate style1.css
#
# */
#
#
# </xmp>
# </pre>

# %% [markdown]
# <pre>
# <xmp>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Giphy Api Search App V1</title>
#     <link rel="stylesheet" href="css/index.css">
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Sofia">
#     <script src="js/index.js"></script>
# </head>
# <body onload="page_load()">
#     <nav>
#         <a href="index.html"><img src="logo-1.png" width="100" height="30" alt="logo-1"></a>
#         <a href="#">About</a>
#     </nav>
#     <main class="global-center-page">
#         <header>
#             <h2 class="h2-style-1">
#                 Giphy Api Search App V1
#             </h2>
#         </header>
#         <p></p>
#             <div>
#                 <input type="text" id="txtsearch" placeholder="# enter text to search" maxlength="25">
#                 <button onclick="btnSearch()">search</button>
#                 <a href="#" onclick="lnkClear()">clear</a>
#             </div>
#         <p></p>
#         <div id="divdisplayinfo" class="div-scroll-1">
#         </div>
#         <p></p>
#     </main>
#     <p></p>
#     <footer class="global-footer">
#         <p>Footer @ 2025</p>
#     </footer>
# </body>
# </html>
# </xmp>
# </xmp>

# %%
# %%html
# <pre>
# <xmp>
#   .global-center-page {
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
# }
#
# .global-footer {
#     text-align: center;
# }
#
#
# .div-scroll-1 {
#     /*desktop, tblet screens*/
#     display: flex; /*adjust screen to any screen size*/
#     width: 500px;
# }
#
#
# .div-scroll-2 {
#     border: 1px solid #000000;
#     width: 400px;
#     height: 200px;
#     word-wrap: break-word;
#     overflow-x: hidden;
#     overflow-y: auto;
# }
#
# /*
# media query - adjust screen based on screen width or height
# */
#
# /*
# add google font
# */
# .h2-style-1 {
#     font-family: "Sofia", sans-serif;
# }
#
# /*
# add scss - css compiler
# */
#
# /*
# add media query for differtent screen sizes
# */
# /*
# @media only screen and (max-width: 450px) {
# */
#
# /* when screen size is <= 350px - apply css code */
# @media only screen and (max-width: 350px) {
#
#     /*mobile screen = screen size 350px */
#     .div-scroll-1 {
#         width: 200px;
#         background-color: rgb(109, 100, 160);
#     }
#
# }
#
#
# </xmp>
# </pre>

# %% [markdown]
# <pre>
# <xmp>
# function page_load(){
#
#     const msgText = "# index: page load"
#
#     console.log(msgText.toUpperCase())
# }
#
#
# function giphyApiDemo1()
# {
#
#     let msgText = "# page4: giphyApiDemo1"
#
#     console.log(msgText.toUpperCase())
#
#     const divdisplayinfo = document.getElementById("divdisplayinfo");
#
#     if (divdisplayinfo == null | divdisplayinfo == undefined){
#         msgText = "## Page3 - divdisplayinfo not found"
#         console.log(msgText)
#         return false;
#     }
#
#     divdisplayinfo.innerText = msgText;
#
#     //giphy url and api key
#
#     const _search_text = "cars" //input text fields
#     const _giphy_ApiKey = ""
#     const _giphy_result_data_file = "./data/giphy2.json";
#     const _giphyApi_Url = `https://api.giphy.com/v1/gifs/search?api_key=${_giphy_ApiKey}&q=${_search_text}&limit=25&rating=g`;
#
#     //fetch - then - promise - non-blocking - javascript call then when data is available
#     //another way of implementing promise = async/await
#
#     //inline or 1 line if statement
#     let _request_url = (_giphy_ApiKey.trim().length == 0)? _giphy_result_data_file : _giphyApi_Url;
#
#     console.log("---- _request_url---- ");
#     console.log(_request_url)
#     console.log("")
#
#     fetch(_request_url)
#     .then(response => {
#       if (!response.ok) {
#         //throw/raise - generate or a error and descrption
#         throw new Error('Network response was not ok');
#       }
#       //-- convert data from text to json
#       return response.json();
#     })
#     .then(data => {
#
#         console.log("#### giphy fetch.promise then - post data ###")
#         console.log(data);
#
#         console.log("")
#         console.log("-------- giphy json data as string ----")
#         //console.log(JSON.stringify(data))
#         console.log("")
#
#         const _image = data.data[0].images.original.url;
#
#         console.log("-- image ---");
#         console.log(_image)
#         console.log("")
#
#         //retrieve giphy data
#         const giphapi_image = `<img width='200' height='150' src='${_image}'>`
#
#         divdisplayinfo.innerHTML = giphapi_image
#
#     })
#     .catch(error => {
#       console.error('## There was a problem with the fetch operation:', error);
#       divdisplayinfo.innerText = error;
#     });
#
#     console.log("..continue fetching gphy data...demo of non-blocking code")
#     divdisplayinfo.innerText = "..continue fetching giphy data...demo of non-blocking code";
#
#
#     //verify root or starting element can be a [] or {}
#
#     //verify invalid, valid document
#
#     //retieve nested json document fields
#
#     //loop through json documents , nested loops
#
#     //verify element level or starting element can be a [] or {}
#
#     //retiieve nested json document fields or array fields reference
#
#     //verify element level or starting element can be a [] or {}
#
#     //convert json string to json object
#
# }
#
#
# function btnSearch(){
#
#   let msgText = "# index: btnSearch" //string
#   console.log(msgText.toUpperCase());
#
#   //select text field and display div using document.getElementById
#   const txtsearch = document.getElementById("txtsearch"); //HTMLElement or null
#   const divdisplayinfo = document.getElementById("divdisplayinfo"); //HTMLElement or null
#
#   //validate if text field and display div is not null, if so and exit function
#   if(txtsearch == null){
#       msgText = "# txtsearch field not found"
#       console.log(msgText)
#       return false //stop onclick and exit function
#   }
#
#   if(divdisplayinfo == null){
#       msgText = "# divdisplayinfo field not found"
#       console.log(msgText)
#       return false //stop onclick and exit function
#   }
#
#   //######## other if condition examples ####
#   //if(txtsearch != null) -> not null
#   //if(txtsearch == null ! divdisplayinfo == null)  -> or
#   //if(txtsearch == null & divdisplayinfo == null) -> or
#
#   //validate if text field is empty, if so exit function
#   if(txtsearch.value.trim().length == 0) {
#       msgText = "# please enter a valid search text"
#       console.log(msgText)
#       divdisplayinfo.innerText = msgText
#       return false //stop onclick and exit function
#   }
#
#   //display search text in display div
#   msgText = "# searching for: " + txtsearch.value
#
#   //divdisplayinfo.innerHTML = "<br>" + msgText + "</b>"
#   divdisplayinfo.innerText = msgText;
#
#   //--- Giphy Api Search code ------
#
#       //giphy url and api key
#
#       const _search_text = txtsearch.value //input text fields
#       const _giphy_ApiKey = ""
#       const _giphy_result_data_file = "./data/giphy2.json";
#       const _giphyApi_Url = `https://api.giphy.com/v1/gifs/search?api_key=${_giphy_ApiKey}&q=${_search_text}&limit=25&rating=g`;
#
#       //fetch - then - promise - non-blocking - javascript call then when data is available
#       //another way of implementing promise = async/await
#
#       /*
#         let _request_url = ""
#
#         if(_giphy_ApiKey.trim().length == 0) {
#         _request_url = _giphy_result_data_file
#         }
#         else
#         {
#         _request_url = _giphyApi_Url;
#         }
#
#         also: optional: optimization, code refactoring, update a variable in condenced statement
#         similar to ? :
#         used whith nested code/nested updates
#
#         ?? -- chek if variable is null else use variable
#         || -- chek if variable is null else use variable
#         && -- chek if variable is null else use variable
#
#         */
#
#       //inline or 1 line if statement
#       let _request_url = (_giphy_ApiKey.trim().length == 0)? _giphy_result_data_file : _giphyApi_Url;
#
#       console.log("---- _request_url---- ");
#       console.log(_request_url)
#       console.log("")
#
#       fetch(_request_url)
#       .then(response => {
#         if (!response.ok) {
#           //throw/raise - generate or a error and descrption
#           throw new Error('Network response was not ok');
#         }
#         //-- convert data from text to json
#         return response.json();
#       })
#       .then(data => {
#
#           console.log("#### giphy fetch.promise then - post data ###")
#           console.log(data);
#
#           console.log("")
#           console.log("-------- giphy json data as string ----")
#           //console.log(JSON.stringify(data))
#           console.log("")
#
#           let _image = "";
#
#           if(data == null | data.data.length == 0){
#             divdisplayinfo.innerText = "# no results found"
#             return false;
#           }
#
#           _image = data.data[0].images.original.url;
#
#           console.log("-- first image ---");
#           console.log(_image)
#           console.log("")
#
#           //retrieve giphy data
#           //const giphapi_image = `<img width='200' height='150' src='${_image}'>`
#
#           //display multiple images
#           //build dynamic html in string or using DOM to dynamically append html elements
#
#           //add css style
#           let _html = "<div>"
#
#           for(i=0;i<data.data.length;i++)
#           {
#             //unit test: display 5 images , exit loop
#             if(i>10)
#             {
#               //ext loop
#               break;
#             }
#
#             _image = data.data[i].images.original.url;
#             _html += `<img width='200' height='200' src='${_image}' style='padding:5px'>`
#             //display 3 images per row
#           }
#
#           _html += "</div>"
#
#           console.log("-------------- html string ----------")
#           console.log(_html)
#           console.log("")
#
#           divdisplayinfo.innerHTML = _html
#
#       })
#       .catch(error => {
#         console.error('## There was a problem with the fetch operation:', error);
#         divdisplayinfo.innerText = error;
#       });
#
#       console.log("..continue fetching gphy data...demo of non-blocking code")
#       divdisplayinfo.innerText = "..continue fetching giphy data...demo of non-blocking code";
#
#
#   //--- Giphy Api Search code ------
#
#   //txtsearch.value = ""; //clear text field
#   txtsearch.focus(); //move keyboard cursor to text field
#
# }
#
# function lnkClear(){
#
#   let msgText = "# index: lnkClear"
#   console.log(msgText.toUpperCase());
#
#   //select text field and display div using document.getElementById
#
#   //const txtsearch = document.getElementById("txtSearch"); //HTMLElement or null
#   const txtsearch = document.getElementById("txtsearch");  //HTMLElement or null
#   const divdisplayinfo = document.getElementById("divdisplayinfo");  //HTMLElement or null
#
#   //validate if text field and display div is null, if so and exit function
#   //-- undefined = field was not definded or created
#   //-- null - field was defined and does not have a value
#   //-- undefined variable is a variable that was not ceeated
#
#   //const var1; //null variable - defined but does not have any value
#
#   //if(txtsearch == null | txtsearch1 == undefined) {
#   if(txtsearch == null | txtsearch == undefined) {
#       msgText = "# txtsearch is null"
#       return false;
#   }
#
#   txtsearch.value = ""; //clear text field
#   txtsearch.focus(); //set keyboard focus to the text field
#
#   //divdisplayinfo.innerText = ""; //clear div content
#
# }
#
#
# </xmp>
# </pre>
