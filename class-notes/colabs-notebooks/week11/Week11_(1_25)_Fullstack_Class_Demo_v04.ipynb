# %% [markdown]
# # Week 11 topic summary
# - Rest API fundamentals
# - Sql fundamentals
# - Demo react frontend user, login, register, dashboard app
# - Demo nodejs/express backend api
# - course summary
#
# ## Class weekly demos
# - https://github.com/dgilbert-quickstart/weekly-class-demos.git
#
# ### Data structures and algorithm theory
#   - course pdf document reference and examples
#   - modern javascript es5+
#   - array, list, set, map/dictornary, tuple, queue, stack, other
#   - data structure fundamentals
#   - demo data structures crud, loop
#   - demo object oriented programming
#
# ### JavaScript Objects and OOP Programming with JavaScript
#   - https://www.w3schools.com/Js/js_classes.asp
#   - modern javascript es5+
#   - code reuse
#     - es4 function objects
#     - es6+ oop
#     - constructor,  inheritance, encapsolation, polymorphism
#   - functional programming, grouped funcrtions , modular programming
#     - map, reduce, foreach, other
#
# ##Web development workflow summary
# - **frontend** website development
#   - 1. **vs.code** - create website html/css/js
#     - custom or manual web development
#     - preview website using live server
#     - see: step-by-step notes provides
#   - 2. **nodejs**  - create website html/css/js
#     - custom or manual web development
#     - npm init -y
#     - package.json
#     - .gitignore
#     - install/uninstall npm packages
#     - see: step-by-step notes provides
#   - 3. **react** frontend website html/css/js
#     - create react application using
#       - create-react-app
#       - yarn
#       - vite
#       - other
#     - react generate html/css/js
#     - see: step-by-step notes provides
#   - 4. **backend** nodejs webiste, api, programs, development
#     - npm init -y
#     - package.json
#     - .gitignore
#     - install/uninstall npm packages
#     - nodejs backend code run on the machine/server in the background
#     - or can create nodjs websites or nodejs api or batch programs
#     - backend programs does not require a web screen
#     - run backend javascript code using **node** program
#     - see: step-by-step notes provides
#
# ### Introduction to Nodejs
#   - https://www.w3schools.com/nodejs/
#   - https://nodejs.org/en/download
#   - nodejs,js program/websever us to build frontend and backend js applications
#   - nodejs is also a js build tools used to generate js code
#   - installing nodejs
#   - Nodejs fundamentals
#   - npm package manager
#     - create a nodejs project
#     - install/un-install javascript libraries
#   - nodejs backend server side demo app
#   - nodejs frontend client side demo app
#
# # npm package website
# - javascript librraies created by other developers
# - https://www.npmjs.com/search?q=repository
#
# ### Introduction to React
#   - https://www.w3schools.com/react/default.asp
#   - SPA - Single page application ie: React, Angular, Vue
#   - Rapidly create a large dynamic websites/webpages
#   - ie: ecommerce, social media, spotify, shopify, facebook,gaming,other
#   - react uses core javascript and moders javascript in react
#   - react uses jsx - modified version of html
#   - react uses virtual DOM in memory copy of browser DOM
#   - virtual DOM is used to sync in-momery DOM with browser DOM
#   ie: for fast reactive websites
#   - react generates dynamic DOM
#   - react generates backword compatable browser javascript code
#   - install nodejs create-react-app program
#   - create a nodejs react project
#     - install/un-install react javascript libraries
#   - React fundamentals
#   - components
#   - react router
#     - navagation menu
#   - react hooks
#   - data structures crud, loop
#   - contact us
#   - deploy react app to github pages
#
# ### Deploy react app to github pages
#   - demo deploy a react app to github pages
#
# ## Principles of Software Engineering II: System Design

# %% [markdown]
# #week 4-5 top summary
#   - https://www.w3schools.com/js/
#   - javascript programming intro
#     - es1-es6+
#       - Js 1..4 - 1997-2008
#       - Es5 - 2009+
#       - Es6 - 2015+ 2020
#     - variables, if, while
#     - array
#     - object
#     - json data
#     - other
#   - dynamic programming
#   - static websites , static web pages
#     - dynamic websites ie: dynamic web pages
#     - pre- react javascript dynamic websites
#     -  event:mouse, keyboard, page, timer, DOM-Document Object-Model, code actions
#     - event attribute js script reference
#     - page script js refence
#     - external file js script refence
#   - demo dynamic web applications
#     - es1-4,es5,es6+
#     - inteactive web applications
#     - generating html using the DOM
#     - selecting DOM elements
#     - wireframe, user stories, githubpages, git clone
#     - display date/time
#     - array introduction
#     - invoice/inventory claculator
#     - contact form validation
#     - ecommerce apps
#     - todo list app or task management
#     - shopping cart application
#     - display web data app ie: json placeholder
#     - javascript games ie: canvas, tic-tac-toe, other
#     - other
#   - deply website to github pages
#   - Json document introduction demo
#   - Query REST api introduciton demo
#   - demo project #2 web application
#   - search engine demo app
#   - giphy api
#     - https://giphy.com/
#     - Giphy api introduction demo
#   - Rest API  -  Representational State Transfer API,
#     - A way for applications to communicate with each other over the interne
#     - Retrieve and update data from other websites
#     - get, post, put, delete
#     - json data
#     - promise, async/await programming
#     - non-blocking api call promise, async/await
#   - css compiler SCSS introduction
#     - css compiler SCSS introduction  demo
#   - css media queries - responsive websites
#     - css media queries - responsive websites demo
#   - other

# %% [markdown]
# # Week (1-2) - Topic summary
#   - HTML5
#   - Nav menu
#   - layout
#   - Css
#   - Bootstrap
#   - Git, Github
#   - Github pages
#   - vs.code
#     - vs.code extensions
#   - browser devtools
#   - Software Engineer Development/Tools/Management
#   - Product Development/Tools/Management

# %% [markdown]
# #Manually deploy react app
# ----------------------------------
#
# 1. create a public repository or use an existing repoitory
# 2. create "gh-pages" branch or is exist delete all files from "gh-pages" branch
# 3. build react project
# 4. upload react build files to gh-pages branch
# 5. delete repository readme.md file if exist
#    note: you should now be able to browse to your react app at the repo github pages: setting/pages
# 6. re-build your react app
# 7. delete repo "gh-pages" branch files
# 6. re-upload build files to repo "gh-pages"
#
#
# - note: github will enable github pages for this repo and url
# - preview in repository settings/pages

# %% [markdown]
# ## Hashrouter error
# <pre>
# <xmp>
# Error
# ================================================
#
# Uncaught SyntaxError: Cannot use 'import.meta' outside a module (at main.c4b18fb8a58981fb2d94.hot-update.js:5475:12)
# After deploying my page is still blank
#
# natgallagher 19:42
# It says (at bundle.js:33930:12) what is bundle?
#
# ##############################
#
# Create react app and browser router may have upda upgraded
#
# “@testing-library/react” the working version is
# 16.2.0 and the app not working is version 16.3.0
#
# ==================================
# Solution #1
# ==================================
#
# use earlier router versio
# "react-router-dom": "^7.5.0"
#
# # stop react app
# ctrl+c
#
# # use realier version of react-router-dom
#
# [sudo] npm install -D react-router-com@7.4.0
# [sudo] npm install -D react-router-com@7.4.1
#
# ================================
# Solution #2
# ================================
# 1. create a new react app folder in cloned directory ie: dashboard-app-v03
# 2. copy a previous working react app files into newly created react app folder
#    (including react-router-dom, gh-pages)
# 3. [sudo] npm install
# 4. edit file, update to wireframe
# 5. [sudo] npm start
#
# -----------------------------
# Solutiopn #3
# -----------------------------
#
# Stop react app
# ctrl+c
#
# --- App.js -----
#
# import {BrowserRouter, Routes, Route} from "react-router-dom"
# //import {HashRouter, Routes, Route} from "react-router-dom"
# import Home from "./components/Home"
# import './App.css';
#
# function App() {
#   return (
#     <>
#       <BrowserRouter>
#         <Routes>
#           <Route path="/" element={<Home/>}/>
#         </Routes>
#       </BrowserRouter>
#     </>
#   );
# }
#
# export default App;
#
# </xmp>
# </xmp>

# %% [markdown]
# #demo daskboard register login react app
#   - wireframe
#     - login, register, dashboard
#   - deploy react app to github pages
#   - react navigation
#   - git update
#   - communicate to backend nodejs/express api
#     - user login, register
#
# ### wireframes
#
# <pre>
# <xmp>
#
# Login
# -----------------
# user name : _____________
# password: _____________
#
# register
#
# [submtt] [clear]
#
#
# Register
# -----------------
# user name : _____________
# password: _____________
# confirm password: _____________
#
# [submtt] [clear]
#
#
# Dashboard
# -----------------
# Weleomr to Dashboard    username [logout]
#
# link 1
# link 2
# link 3        link1 info
# link 4
# link 5
# link 6
#
# </xmp>
# </pre>

# %% [markdown]
# #SQL Fundamentals
#
# <pre>
# <xmp>
# ## Introduction to SQL
# - https://www.w3schools.com/sql/
#
# ##  nodejs sqlite3 CRUD examples
# - https://coderslegacy.com/javascript-sqlite3-tutorial-for-beginners-node-js/
# - https://medium.com/swlh/creating-a-crud-application-using-node-js-and-sqlite3-a57d4a39ab69
# - https://sqldocs.org/sqlite/sqlite-nodejs/
# - https://www.sqliz.com/posts/javascript-crud-sqlite/
#
# ## Introduction to SQL
# - https://www.w3schools.com/sql/
# - Database = file containing structured data ie: table/schema, rows, columns
# - SQL is a standard language for storing, manipulating and retrieving data in databases.
# - SQL - universal/common language/code used to manipulate or retrieve data from a database.
# - Our SQL tutorial will teach you how to use SQL in: MySQL, SQL Server, MS Access, Oracle, Sybase,
#   Informix, Postgres, and other database systems.
#
# ## SQLite = portable text based full featured database
#
# ## Structured query language
# - Create a database to store data
# - create a table structure to save data
# - add, update, delete data using sql command
# - RDBMS - relational management system
# - data can be related and joined
# - ie: MySql, Postgressql, Oracle, Sql Server, Other
# - sqlite - full-featured portable sql text-based database
#
# ## SQLite = portable text based full featured database
# - download/install sqlite db browser
# - https://sqlitebrowser.org/dl/
# -** windows: **
# -** DB Browser for SQLite - Standard installer for 64-bit Windows **
#
# <pre>
# <xmp>
#
# --------------------------------------
# DEMO SQL Db Browser db #1
# --------------------------------------
# -- create database "demodb1"
# -- save sqlite db browser session
# -- create new query tabs
# -- rename query tabs
# -- copy and use sqlite database to application
#
# ## Database  Create table Summary
# - table name: contact
# - fields
# -  Type - number, string, blob/object
# -  NN - Not null, must not be null
# -  PK - Primary key - key can not be duplicate , primary key is also unique
# -       used as default data sorting
# -  AI - Auto increment
# -  U - unique - does not be duplicate , primary key is also unique
# -  Default - add defult value when field is empty
# -  Check - additional sql field validation
#
# * create table "user"
#   field:
#     id        int nn pk un
#     username  text nn
#     password  text nn
#
# * insert data
#
# * query data
#
#   select *
#   from user
#
#   select id, name, password
#   from user
#   ;
#
#   select *
#   from user
#   limit 2
#   ;
#
#
# -- Where statement
#
#
# </xmp>
# </pre>

# %% [markdown]
# #SQL Query demo #1
# - create a database ie: dasbboard
# - create table : user
#   - id integer not null autoincrement unique primary key
#   - username text not null unique
#   - password text not null
#
# <pre>
# <xmp>
# CREATE TABLE "user" (
# 	"id"	INTEGER NOT NULL UNIQUE,
# 	"username"	TEXT NOT NULL UNIQUE,
# 	"password"	TEXT NOT NULL,
# 	PRIMARY KEY("id" AUTOINCREMENT)
# );
# </xmp>
# </pre>
#
# ### Query data - ie: login page
#   - sql code - select , where and
#
# <pre>
# <xmp>
# /*
# sql demo #1 - get all users
# - display all columns
# - display all rows
#  note: not reccomended ie: 1mil+ rows, quiry timeout
# */
# select *
# from user
#
# ---------------------------
#
# /*
# sql demo #2 - get all users
# - display all columns
# - display all rows
#  note: not reccomended ie: 1mil+ rows, quiry timeout
#  use limit [number of rows]
#  */
# select *
# from user
# limit 10
#
# ---------------------------
#
# /*
# sql demo #3 - get all users
# - display username and password
# - display all rows
#  note: not reccomended ie: 1mil+ rows, quiry timeout
#  use limit [number of rows]
#  */
# select username, password
# from user
# limit 10
#
#
# -------------------------
#
# /*
# sql demo #4 - get all users ie: login page
# - display username and password
# - display specified username and pasword
#  note: not reccomended ie: 1mil+ rows, quiry timeout
#  use limit [number of rows]
#  */
# select username, password
# from user
# where username = "userone"
# and password = "pwd1"
# limit 10
#
# --------------------------------
#
#
# </xmp>
# </pre>
#
# ### add sampe data - ui and sql code - ie: register page
#   - insert new data - ui and sql code
#   - insert into
#
# <pre>
# <xmp>
# </xmp>
# </pre>
#
# ### review sql update, delete
#
#
# <pre>
# <xmp>
# /*
# display all users
# select/retrieve all columns
# select/retrieve all rows
# */
# select *
# from user
#
# ------------------------------
#
# /*
# display all users
# select/retrieve username, password
# select/retrieve all rows
# */
# select username, password
# from user
# ;
#
# ------------------------------
#
# /*
# display all users
# select/retrieve username, password
# select/retrieve a specified row
# */
# select username, password, updateddate
# from user
# where username = "userone"
# and password = "pwd1"
# ;
#
#
#
# ------------------------------
#
#
# ------------------------------
#
#
# </xmp>
# </pre>

# %% [markdown]
# # Product table - CRUD demo
#
# <pre>
# <xmp>
# =================================================
# product CRUD example #2
# =================================================
#
# product
#  id    primary key
#  name  string not null
#  date  string null
#  price numeric not null
#
#
# name, date, price
# item1, 5/1/21, 112.32
# item2, 1/5/21, 312.42
# itema, 1/20/22, 89.36
# itemb, 12/5/23, 238.23
# itemc, 8/10/23, 73.2
# itemd, 11/10/24, 52.36
#
# -----------------------------
# SQL Queries
# -----------------------------
# - create table
# = add update delete data
# - query data
#
# SELECT
# WHERE
# LIMIT
#
# INSERT
# UPDATE
# DELETE
#
#
# </xmp>
# </pre>
#
#
# ##Queries
# <pre>
# <xmp>
#
# CREATE TABLE "product" (
# 	"id"	INTEGER NOT NULL,
# 	"name"	TEXT NOT NULL,
# 	"date"	TEXT,
# 	"price"	NUMERIC NOT NULL,
# 	PRIMARY KEY("id" AUTOINCREMENT)
# );
#
# ---------------------------------------
#
# /*
# insert query 1
# */
# insert into product(name,date,price)
# values ("itema","1/20/22",89.36)
#
# ---------------------------------------
#
# SELECT *
# from product
# limit 10
#
# ---------------------------------------
#
# SELECT name,date,price
# from product
# limit 10
#
# ---------------------------------------
#
# SELECT name,date,price
# from product
# WHERE price > 100
# limit 10
#
#
# ---------------------------------------
#
# SELECT name,date,price
# from product
# WHERE name like "%item%"
# and price > 100
# limit 10
#
#
# ---------------------------------------
#
# ---------------------------------------
#
#
# </xmp>
# </pre>

# %% [markdown]
# # connecting to sqlite3 database using javascript
#
# - https://coderslegacy.com/javascript-sqlite3-tutorial-for-beginners-node-js/
# - connect to db
# - select data
# - insert data
#
# <pre>
# <xmp>
#
# //https://coderslegacy.com/javascript-sqlite3-tutorial-for-beginners-node-js/
#
# const sqlite3 = require('sqlite3').verbose();
#
# //windwos or macos or linux
# //let _dbname = `demodb1.db`
# let _dbname = "src\\data\\dashboard.db"
#
# //macos, linux os
# //let _dbname = "src/data/demodb1.db"
# //let _dbname = "src/data/dashboard.db"
#
# let db = new sqlite3.Database(_dbname, sqlite3.OPEN_READWRITE, (err) => {
#   if (err) {
#     return console.error(err.message);
#   }
#   console.log('Connected successfully.');
# });
#
# /*
# db.all("SELECT * FROM user", [], (err, rows) => {
#     console.log(rows)
# })
# */
#
# db.get("SELECT * FROM user", [], (err, row) => {
#     if (err) {
#         throw err;
#     }
#     console.log(row);
# });
#
#
# </xmp>
# </pre>

# %% [markdown]
# #Nodejs express webserver Demo #1
# - command line: node --version
# - nodejs version 20.x and above
#   - nodejs backend program/webserver - non-browser javascript development
#   - nodejs frontend website
#     - npm - node pacakeg manager - tool used to create a nodejs project and install/un-install javascript libraries
#     - creating a nodejs project
#     - package.json file
#     - .gitignore file
#     - node_modules
#     - installing/un install - frontend/backend development javascript libraries
#     - react uses nodejs and features mentioned

# %% [markdown]
# #nodejs express - dashboard app v1
#
# <pre>
# <xmp>
# ===================================================
# Node js/express backend dashboard api demo #1
# ===================================================
#
# 1. create public repository ie: deshboard-api-app-v1
#
# 2. from vs.code clone repo
#    goto project root folder
#    goto command terminal
#    clone repo
#    cd into cloned folder
#
# 3. create a package.json file
# goto project folder before "src"
# npm init
# ## accept all defaults
# or
# npm init -y
# ## node will create package.json
#
# 4. add .gitignore file
#   from project root folde enter the following in .getignore file
#
#   node_modules
#   .env
#
# 5. add a npm javascript libraries
#  from root project folder goto command line and enter
#  express - minimal nodejs web server
#  body-parser - converts form post to json
#  cors - allow localhost to make request to other localhost web applications
#  sqlite3 - javascrpit library to manipulate sqlite3 database
#
# npm install express body-parser cors sqlite3
#
# 6. copy sqlite dasboard database to src/data folder
#
# 7. create server index.js file
#   src\index,js
#
# 8. server code:
#
# const express = require("express");
# const cors = require("cors");
# const app = express();
#
# //cors allow access to same site or other localhost
# app.use(cors())
#
# //localhost port range - 3000 - 9999
# const SERVER_PORT = 8080;
#
# app.get("/", (req,res) => {
#     const _msg = "# Demo node express api 1.0.0";
#     console.log(_msg)
#     res.send(_msg)
# });
#
# app.get("/about", (req,res) => {
#     const _msg = "# Demo node express api 1.0.0 - about route";
#     console.log(_msg)
#     res.send(_msg)
# });
#
# app.get("/test1", (req,res) => {
#     const _msg = "# Demo node express api 1.0.0 - test1 route";
#     console.log(_msg)
#     res.send(_msg)
# });
#
# //-other - POST, DELETE, PUT
#
# //-start node exporess web server - ie: live server
# app.listen(SERVER_PORT, ()=>{
#     let _msg = "node express websever running at port: " + SERVER_PORT;
#     console.log(_msg);
# })
#
# 9. run server
#   from project root folder enter the following:
#   node src/index.js
#
# 10. update github
# from root project folder
# goto command terminal
# git add, commit, push
#
# 11. run server
#
# note: access localhost server from browser
# http://localhost:8080/test1
#
# note: access localhost server fromcommand line
# curl http://localhost/test1
#
# 12. deply nodejs express backend server ie: replit.com
#
# login to replit.com
# select replit nodejs project
# copy server file(s) from localhost to replit.com nodejs project
# ie: index.js, test.db3
# start replit.com nodejs app
#
# 13. note: access replit.com nodejs server from browser
# http://replit.com-url/test1
#
# note: access replit.com server from command line
# curl http://replit.com-url/test1
#
#
# </xmp>
# </pre>

# %% [markdown]
# # Replit.com demo
# - free virtual compueter
# - host free frontend and backend
# - many stack, javascript, other
#
# - https://replit.com/
# - signup free account
# - development
# - create a node js application (stack)
#
# #Deploy code to replit.com
#
# <pre>
# <xmp>
#   1. access your replit.com , nodejs project - stack
#   2. create data folder, upload your sqlite data file
#   3. create index.js
#   4. copy localhost project index.js code to replit index.js
#   5. add a npm javascript libraries
#   select alltools then select shell and enter
#
#   npm install express body-parser cors sqlite3
#
#   6. run replit.com server using replit.com run button
#   7. copy your replit url from webview
#   8. preview your replit.com server in browser
#
# </xmp>
# </pre>
#
#
# </xmp>
# </pre>
