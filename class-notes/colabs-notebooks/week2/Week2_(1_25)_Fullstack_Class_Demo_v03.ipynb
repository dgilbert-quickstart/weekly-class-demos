# %% [markdown]
# # Week 2 topic summary
#   - front-end development (static frontend web development)
#   - html, css, bootstrap
#   - git, github
#   - deply website to github pages
#
# # introductio to css
#   - https://www.w3schools.com/css/default.asp
#   - css scope
#     - element level css style
#     - page level css style
#     - external css file - reuse in other pages, projects
#     - custom css class name - re-usable css elemnts style ie: variable names
#     - select element by id - ie: id="para-1"
#     - https://www.w3schools.com/cssref/css_selectors.php
#   - container elements ie: div, section
#   - selecting 1 or multiple elements and add css style
#   - webpage layout ie: content columns, rows
#   - center webpage
#   - center, left, right, top, bottom align webpage content
#   - add padding in navigation menu items
#   - show/hide elements
#     - display:none
#     - display: block
#     - display: inline
#   - remove bullited list from unordered list
#     - ul style = "list-style-type: none;"
#   - add element border, padding, margins
#   - wrap content text
#   - scroll content text
#   - mouse hover, animation, other
#   - formatting: color, p,u,i, font, div
#   - css units
#     - https://www.w3schools.com/cssref/css_units.php
#     - fixed measurment: px
#     - relative measurment: %, em
#   - background image
#   - css media query - custom css used to modify / update content when screen width or hight changes ie: (mobile/tablet) etc.
#   - other
#
# # html layout ie: table
#   - https://www.w3schools.com/css/css_table.asp
#   - table, rows, columns
#
# # css horizontal aligned contents ie: div
#   - https://www.w3schools.com/css/css3_flexbox.asp
#   - div - display: flex
#   - other : grid layout
#
# # html form
#   - required field
#   - maxlength, minlength
#   - placeholder
#
# # intro to bootstrap5 (core-js-css)
# - https://www.w3schools.com/bootstrap5/index.php
# - https://www.w3schools.com/bootstrap5/bootstrap_colors.php
#   - no css is required
#   - container
#   - grid system
#   - formatting
#   - navigation
#   - webpage content layout
#   - columns, rows
#   - responsive navigation ie: (mobile, table, desktop)
#   - bootstrap responsive navigation menu
#   - dynamically/responsive adjust screen based on device (mobil/tablet/etc)
#   - mouse hover, animations
#   - pre-defined bootstrap designed components
#   - dsiplay dialog
#   - other
#
# # git/github, github pages
#   - https://github.com
#   - https://www.w3schools.com/git/default.asp
#   - download git command line tool
#     - https://git-scm.com/downloads
#   - used by more than 70% of spoftware developent industry
#   - similar github compatable  tools: gitlab, bitbucket, other
#   - team shared code development
#   - (public private) code repositories ie: vs.code - workspaces
#   - maintain/manage code modifications history ie: commits
#   - clone code to local computer
#   - make local modification and sync code to github
#   - github pages, free online websites
#
# - class website demo or course project
# - Principles of software Engineering Summary/Questions
# - Intro to Ux/Product Management summary/Questions
#
# #macos to install homebrew
# <pre>
# <xmp>
# macos to install homebrew
# ----------------------------
# - goto terminal on a macos
# - then enter
#
# /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
#
# ###############################
#
# brew install git
#
# or
#
# sudo brew install git
#
#
# ###############################
#
# git --version
#
#
# </xmp>
# </pre>

# %% [markdown]
# #Week 1 topic summary
# - fullstack software engineer intro
#   - javascript tech stack
# - google colabs notebook intro
# - markdown intro
#  - https://www.markdownguide.org/cheat-sheet/
# - html intro
# - css intro
# - vs.code
#   - workspace
#   - extensions
# - first website
# - chrome devtools - ie: inspect
# - webpage validator
#   - https://validator.w3.org/
# - course project 1 review
#   - wireframe
#   - use stories
# - course project 1 demo
#
# # Course notes, documents and lab exercises
# - https://github.com/dgilbert-quickstart
# - https://github.com/dgilbert-quickstart/weekly-class-demos
#
# # Software engineering fundamentals
# - Html, Css, Responsive layout, Bootstrap, Gighub, Github pages,
# - Core js, es1-6+, DOM, Data Structures, nodejs, React, Rest Api,
# SQL Other
# - Frontend, Middleware - Rest Api, Backend Sql Database
# - Real world, best practices
# - Step by step, Demo Labs and Demo Applications
#
# ## Week 1 - Step-by-Step class Demos and Exercises
# - ### Introduction to Fullstack Software Engineering - Javascript
#   - ### Introduction to Software engineering
#   - ### System Development, Project Management, System Design
#   - ### DevTools / Install
#     - google CoLabs
#       - https://colab.research.google.com/
#
#       - colabs introduction
#         - https://www.marqo.ai/blog/getting-started-with-google-colab-a-beginners-guide
#
#       - colabs markdown introduction
#         - https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Cheat_sheet_for_Google_Colab.ipynb
#
#       - colabs %%html, %%javascript other
#         - https://ipython.readthedocs.io/en/stable/interactive/magics.html
#
#     - vs.code
#       - https://code.visualstudio.com/download
#   - ### Architecture overview
#     - Javascript eco systems
#     - Font-end
#     - Backend
# - ### Introduction to Google Colabs
#   - html demo
#   - javascript demo
# - ### Introduction to vs.code
#   - folders/workspace
#   - extensions
#     - html preview
#     - live server
# - ### Introductio to Markdown
#   - https://www.markdownguide.org/cheat-sheet/
#   - demo class project README.md
#
#   - vs.code markdown preview extension
#   - Markdown Preview Enhanced
#   - Yiyi Wang
#   - right-click on file then select "markdown preview enhanced"
#
# - ### Introduction to HTML
#   - https://www.w3schools.com/html/default.asp
#   - formatting: p,u,i, font, div
#   - img, audio, video
#   - layout, table, css
#
# - ### first website v1.0.0
#   - index
#   - about
#   - contact
# - nav bar
# - html form
# - layout
# - Other
#
# - ### Introduction to HTML document validation
#   - https://validator.w3.org/
#
#
# - ### Chrome browser DevTools introduction
#   - right click, then select, inspect
#   - source, console, network , other

# %% [markdown]
# - Principles of software Engineering Summary/Questions
# - Intro to Ux/Product Management summary/Questions
# - Other
#   - course topics, class demos and course labs cover 90%-95% industry javascript, html, css software engineering development/product management, fundamentals, tools and workflows.

# %% [markdown]
# - ### Class Project #1 overview
#  - user stories
#  - wireframe

# %% [markdown]
# # Introduction to HTML demo
# - https://www.w3schools.com/html/default.asp
#
# # HTML5 elemnets
# - https://www.w3schools.com/html/html5_semantic_elements.asp
#   - Semantic tags
#   - SEO - Search engine optimizaton
#   - screen readers
#   - accessablity
#
# <pre>
# <xmp>
#   <header> - Defines the header of a page or a section (can include navigation, logos, etc.).
#   <footer> - Defines the footer of a page or a section (typically for copyright, contact information).
#   <article> - Represents a self-contained piece of content (e.g., a blog post, news article).
#   <section> - Defines a section of content, typically with a heading.
#   <nav> - Defines navigation links.
#   <aside> - Represents content aside from the main content (e.g., sidebars, related links).
#   <main> - Represents the main content of the document (unique to the page).
# </xmp>
# </pre>
#
# #HTML Demo topics
# - html
# - html5
# - formatting
# - list
# - hyper links
# - navigation
# - image, audio, video
# - forms
# - layout
# - test website using google colabs
# - validate website
#   - https://validator.w3.org/
# - browser devtool
# - preview webpage code ie: right-click then select inpect
# - other

# %% [markdown]
# # Intrduction to css - cascading style sheets
# - https://www.w3schools.com/css/default.asp
# - selecet element, then apply style
# - element style
# - page level style
# - global style or website leve style
# - style class - re-usabel style ie: varible in programming
#
# # style key : value
# - many styles are shared in all elements
# - font, color, backgound,
# - alignment
# - padding, margin, border
# - show/hide element - ie: display
# - animatinon , opacity
# - centering page or content
# - content layout , grid, flexbox, table
# - media query - update webpage based screen width/height
#
# <pre>
#
# element style - select the element, then apply style
# css - cascading - overriding - element style always override global or page level styles
#
# body {
#   background-color: lightblue;
# }
#
# h1 {
#   color: white;
#   text-align: center;
# }
#
# p {
#   font-family: verdana;
#   font-size: 20px;
# }
#
# </pre>
#
# #css color code
# <pre>
#
# color codes
# -------------------
# a-f
# 0-9
# 6-characters-and-or-digit-combo
#
# #000000 - white
# #ffffff - black
#
# #a00000
# #b00000
# #c00000
# #abcdef
#
# </pre>
#
# <pre>
#   /*
#   css comment
#   page level style
#   select element then add style(s)
#   */
#   h2 {
#       background-color: lightblue;
#   }
#
#   /*
#   cascade - top down
#   css defined after current css will be overridden
#   combines pervious css to cueernt css
#   */
#   p {
#       text-align: center;
#       color:#abcdef
#   }
#
#   p {
#       color:blue
#   }
#
#   span {
#       font-family: 'Courier New', Courier, monospace;
#       color:green
#   }
#
#   label {
#       color:blue
#   }
#
#   /* select multiple elements */
#   ul, ol {
#       list-style-type: none;
#   }
#
# </pre>
#
# #named css intro
# <pre>
# <xmp>
#
# /*
# css comment
# page level style
# select element then add style(s)
# */
#
# /*
# generic style name that can be used in any element
# add named element to a element using class="header-style-1"
# */
# .header-style-1 {
#     background-color: lightblue;
# }
#
# /*
# named style that applys to only css element
# this elemen can ne be applied to other element - only h2
# add named element to a element using class="header-style-1"
# */
# h2.header-style-2 {
#     background-color: lightgreen;
# }
#
# /*
# named #id styles
# adding multinple named styles ie: class to elements
# */
#
# /*
# cascade - top down
# css defined after current css will be overridden
# combines pervious css to cueernt css
# */
# p {
#     text-align: center;
#     color:#abcdef
# }
#
# p {
#     color:blue
# }
#
# span {
#     font-family: 'Courier New', Courier, monospace;
#     color:green
# }
#
# label {
#     color:blue
# }
#
# /* select multiple elements */
# .list-style-1 {
#     list-style-type: none;
# }
#
# /*
# cascade or merger override extend
# */
# ul .list-style-1 {
#
# }
#
# /*
# cascade or merger override extend
# */
# ol .list-style-1 {
#
# }
#
#
# #para-1 {
#     color:rgb(130, 61, 194)
# }
#
# #span-1 {
#     color:#abc123
# }
#
#
# </xmp>
# </pre>
#
# #center page, scroll content, nav spacing, button hover
#
# <pre>
# <xmp>
#
# .center-page {
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
#   }
#
# .scroll-container-text {
#     border: 1px solid #000000;
#     width: 200px;
#     height: 200px;
#     word-wrap: break-word;
#     overflow-x: hidden;
#     overflow-y: auto;
# }
#
# .nav-space-style-1 {
#     padding: 10px;
# }
#
# .nav-space-style-2 {
#     padding-left: 5px;
#     padding-right: 5px;
#     padding-top: 5px;
#     padding-bottom: 5px;
# }
#
# button .cuttom-cursor {
#     cursor: pointer;
# }
#
# </xmp>
# </pre>

# %% [markdown]
# #form bootstrap button style
# #form submit action, method
# #form validation, placeholder, maxlength
#
# #send form data via email
# - formspree.io
# - free account
# - action=/formspree.io/account-access-token
#
# <pre>
# <xmp>
#  <!--
#   action = server url to sedn data to
#   method = how to send the form data, get or post
#     - get - send form data in browser address bar , data size limit of 256k
#     - default = post - send form data in memory , unlimited data size
#   -->
#   <form action="/" method="post">
#       <span>* &nbsp; first name:</span> <input type="text" placeholder="*first name required" maxlength="25" required> <br>
#       <label>last name:</label> <input type="text"  maxlength="25"> <br>
#       <label>* &nbsp; email:</label> <input type="email" placeholder="*email required"  maxlength="100" required> <br>
#       <label>* &nbsp; comment: </label> <br>
#       <textarea cols="30" rows="10" placeholder="*comment required"  maxlength="150" required></textarea>
#       <p></p>
#       <button class="btn btn-primary">submit</button>
#   </form>
# </xmp>
# </pre>
#
# #bootstrap navigation and colors
# - https://www.w3schools.com/bootstrap5/bootstrap_navbar.php
#
# <pre>
# <xmp>
#
# Use any of the .bg-color classes to change the background color of the navbar (.bg-primary, .bg-success, .bg-info, .bg-warning, .bg-danger, .bg-secondary, .bg-dark and .bg-light)
#
# Tip: Add a white text color to all links in the navbar with the .navbar-dark class, or use the .navbar-light class to add a black text color.
#
# ########################
#
# <nav class="navbar navbar-expand-sm bg-dark navbar-dark">
#   <div class="container-fluid">
#     <a class="navbar-brand" href="index.html">Logo</a>
#     <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#collapsibleNavbar">
#       <span class="navbar-toggler-icon"></span>
#     </button>
#     <div class="collapse navbar-collapse" id="collapsibleNavbar">
#       <ul class="navbar-nav">
#         <li class="nav-item">
#           <a class="nav-link" href="about.html">About</a>
#         </li>
#         <li class="nav-item">
#           <a class="nav-link" href="#">Link</a>
#         </li>
#         <li class="nav-item">
#           <a class="nav-link" href="#">Link</a>
#         </li>
#       </ul>
#     </div>
#   </div>
# </nav>
#
# </xmp>
# </pre>
#
# #vs.code samepl text to web page
# - Lorem ipsum
# - example: from vs.code inside an element div, p, etc..
# - lorem
# - lorem20
#
# <pre>
# <xmp>
# intro to vs.code - Lorem ipsum
# ○ https://hipsum.co
# ○ http://pirateipsum.me/
# ○ https://loremipsum.io/ultimate-list-of-lorem-ipsum-generators
# </xmp>
# </pre>
#
#
# #refence to bootstrap templates, themes
#
# - https://www.w3schools.com/bootstrap5/bootstrap_templates.php
# - https://www.w3schools.com/bootstrap5/bootstrap_colors.php
#
# # bootstrap custom class overrides
#
# # bootstrap custom additional themes and classes
# - use bootstrap container, layout
# - add custom css, style

# %%
# %%html
# <style>
# /*
# css comment
# page level style
# select element then add style(s)
# */
#
# /*
# placeholder-named-style
# */
# .container-1 {
#
# }
#
# /*
# generic style name that can be used in any element
# add named element to a element using class="header-style-1"
# */
# .header-style-1 {
#     background-color: lightblue;
# }
#
# /*
# named style that applys to only css element
# this elemen can ne be applied to other element - only h2
# add named element to a element using class="header-style-1"
# */
# h2.header-style-2 {
#     background-color: lightgreen;
# }
#
# /*
# named #id styles
# adding multinple named styles ie: class to elements
# */
#
# /*
# cascade - top down
# css defined after current css will be overridden
# combines pervious css to cueernt css
# */
# p.para-style-1 {
#     text-align: center;
#     color:#abcdef
# }
#
# p.para-style-2 {
#     color:blue
# }
#
# span.span-style-1 {
#     font-family: 'Courier New', Courier, monospace;
#     color:green
# }
#
# label.label-style-1 {
#     color:blue
# }
#
# /* select multiple elements */
# .list-style-1 {
#     list-style-type: none;
# }
#
# /*
# cascade or merger override extend
# */
# ul .list-style-1 {
#
# }
#
# /*
# cascade or merger override extend
# */
# ol .list-style-1 {
#
# }
#
# .nav-space-style-1 {
#     padding: 10px;
# }
#
# .container-space-style-1 {
#     padding-left: 5px;
#     padding-right: 5px;
#     padding-top: 5px;
#     padding-bottom: 5px;
# }
#
# .center-page {
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
# }
#
# footer {
#     text-align: center;
# }
#
#
# #para-1 {
#     color:rgb(130, 61, 194)
# }
#
# #span-1 {
#     color:#abc123
# }
#
#
# </style>

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>css demo - 4</title>
#     <link rel="stylesheet" href="css/page4-css-demo.css">
# </head>
# <body>
#      <!-- navigation menu -->
#     <nav>
#         <a href="index.html"><img src="logo1.png" alt="logo1.png" width="200" height="20"></a>
#         <a href="about.html">About</a>
#         <a href="contactus.html">Contact Us</a>
#         <a href="page1-css-demo.html">css demo 1</a>
#         <a href="page2-css-demo.html">css demo 2</a>
#         <a href="page3-css-demo.html">css demo 3</a>
#         <a href="page4-css-demo.html">css demo 4</a>
#     </nav>
#     <p></p>
#
#      <!-- main -->
#      <main class="center-page">
#
#         <!-- element style - select the element, then apply style -->
#         <!-- css - cascading - overriding - element style always override - global or page level styles -->
#         <header>
#             <h2 class="header-style-1">CSS Demo 4</h2>
#         </header>
#
#         <!-- section -->
#         <section>
#             <!--
#             color codes
#             -------------------
#             a-f
#             0-9
#             6-characters-and-or-digit-combo
#
#             #000000 - white
#             #ffffff - black
#
#             #a00000
#             #b00000
#             #c00000
#             #abcdef
#
#             -->
#             <p class="header-style-1">
#                 Introduction to css
#             </p>
#
#             <p class="header-style-2">center page</p>
#
#             <p class="para-style-1">
#                 paragraph 1
#             </p>
#
#             <p class="para-style-2">
#                 paragraph 2
#             </p>
#
#             <p class="para-style-1 para-style-2">
#                 paragraph 3
#             </p>
#
#             <span>
#                 style sentence 1 - font, color
#             </span>
#
#             <p></p>
#             <label class="label-style-1">
#                 style sentence 2 - spacing , border, padding
#             </label>
#         </section>
#
#           <p></p>
#
#           <p id="para-1">
#               paragraph 4
#           </p>
#
#           <p></p>
#
#           <span id="span-1">
#               paragraph 5
#           </span>
#
#         <p></p>
#         <span class="span-style-1">Item list</span>
#
#         <ul class="list-style-1">
#             <li>item 1</li>
#             <li>item 2</li>
#             <li>item 3</li>
#         </ul>
#
#         <ol class="list-style-1">
#             <li>item a</li>
#             <li>item b</li>
#             <li>item c</li>
#         </ol>
#
#      </main>
#      <p></p>
#
#      <!-- footer -->
#      <footer>
#         <p>footer @ 2025</p>
#      </footer>
#
# </body>
# </html>

# %% [markdown]
# #layout demo
# - table layout
# - https://www.w3schools.com/css/css_table.asp
# - css layout - display: flex
# - https://www.w3schools.com/css/css3_flexbox.asp
# - other: grid

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Layout Demo 1 - table layout</title>
# </head>
# <body>
#
#      <!-- navigation menu -->
#      <nav>
#         <a href="index.html"><img src="logo1.png" alt="logo1.png" width="200" height="20"></a>
#         <a href="about.html">About</a>
#         <a href="contactus.html">Contact Us</a>
#         <a href="page1-css-demo.html">css demo 1</a>
#         <a href="page2-css-demo.html">css demo 2</a>
#         <a href="page3-css-demo.html">css demo 3</a>
#         <a href="page4-css-demo.html">css demo 4</a>
#         <a href="layout-demo-1.html">layout demo 1</a>
#     </nav>
#
#     <p></p>
#
#     <main>
#         <section>
#             <header>
#                 <h2>
#                     Layout Demo 1 - table layout
#                 </h2>
#             </header>
#         </section>
#         <p></p>
#         <div>
#             <table>
#                 <tr>
#                     <th>heading 1</th>
#                     <th>heading 2</th>
#                     <th>heading 3</th>
#                 </tr>
#                 <tr>
#                     <td>col1</td>
#                     <td>col2</td>
#                     <td>col3</td>
#                 </tr>
#             </table>
#             <p></p>
#             <table>
#                 <tr>
#                     <td>col1</td>
#                     <td>col2</td>
#                     <td>col3</td>
#                 </tr>
#             </table>
#             <p></p>
#             <h2>Css Layout - display: flex demo </h2>
#             <p></p>
#             <p>Display : block demo - 1</p>
#             <p></p>
#             <div>
#                 <div> content a </div>
#                 <div> content b</div>
#             </div>
#             <p></p>
#             <p>Display : flex demo - 1</p>
#             <p></p>
#             <div style="display: flex">
#                 <div style="padding-right: 10px;"> content 1 </div>
#                 <div> content 2</div>
#             </div>
#             <p></p>
#         </div>
#     </main>
#
#     <footer>
#         footer @ 2025
#     </footer>
# </body>
# </html>

# %% [markdown]
# # intro to bootstrap5 (core-js-css)
# - https://www.w3schools.com/bootstrap5/index.php
# - https://www.w3schools.com/bootstrap5/tryit.asp?filename=trybs_default&stacked=h
#   - no css is required
#   - container
#   - grid system
#     - https://www.w3schools.com/bootstrap5/bootstrap_grid_system.php
#     - row, col-screen-width-columns size
#     - default screen size ie: sm, lx, xl, xxl, other
#     - all columns-size must add up to 12
#     - example:
#     - col-sm-4, col-sm-4, col-sm-4
#     - col-*-4, col-*-4, col-*-4
#     - col-sm-6, sm-sm-6
#     - col-sm-12
#     - bootstrap will distribute smace for > 12 columns
#     - col-sm-8, col-sm-4, col-sm-2
#     - bootstrap grid hiarchy , example
#     - container>row>col
#     - container>row>col>row>col
#
#
#   - formatting
#   - navigation
#   - webpage content layout
#   - columns, rows
#   - responsive navigation ie: (mobile, table, desktop)
#   - bootstrap responsive navigation menu
#   - dynamically/responsive adjust screen based on device (mobil/tablet/etc)
#   - mouse hover, animations
#   - pre-defined bootstrap designed components
#   - dsiplay dialog
#   - Bootstrap workflow overview
#   - create main bootstrap website (containers-or-flex, layout-row-cols)
#   - depending on website demo, review bootstrap component classes and add to
#   - website: for example: nav, dialog, form, other
#   - layout, responsive design
#   - also bootstrap themes and components
#   - reference bootstap locally in a website
#   - other
#
#
# #bootsrap list
# - https://www.w3schools.com/bootstrap5/bootstrap_list_groups.php
#
# <pre>
# <xmp>
#   <ul class="list-group">
#     <li class="list-group-item">First item</li>
#     <li class="list-group-item">Second item</li>
#     <li class="list-group-item">Third item</li>
#   </ul>
# </xmp>
# </pre>
#
# # Bootstrap forms, buttons
# - https://www.w3schools.com/bootstrap5/bootstrap_forms.php
# - https://www.w3schools.com/bootstrap5/bootstrap_buttons.php
#
# #Bootstrap navigation
# - https://www.w3schools.com/bootstrap5/bootstrap_navbar.php

# %% [markdown]
# #Bootstrap fundamantals
#
# - https://www.w3schools.com/bootstrap5/bootstrap_colors.php
#
#
# <pre>
# <xmp>
# bootstrap color
# -------------------------
# The classes for text colors are: .text-muted, .text-primary, .text-success, .
# text-info, .text-warning, .text-danger, .text-secondary, .text-white, .
# text-dark, .text-body (default body color/often black) and .text-light:
#
#
# </xmp>
# </pre>
#
# # other front-end styling library
# - head link to css library ie: w3-c.org, tailwindcss, materialcss, other
# - documentation class name
# - override css or create custom css
# - themes, component, temaplates
# - customizable
#
#
# <pre>
# <xmp>
# /*
# combine custom css and bootsrap css
# */
#
# .text-primary-1
# {
#     /*
#     add your custom code
#     */
# }
#
#
# .text-primary-2
# {
#     /*
#     bootstrap reccomended step in combining bootstrap code to your own css
#     extending bootstrap
#     */
# }
#
#
# </xmp>
# </pre>

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Bootstrap demo 2</title>
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/bootstrap.min.css" rel="stylesheet">
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/js/bootstrap.bundle.min.js"></script>
# </head>
# <body>
#
#     <!-- navigation menu -->
#     <nav>
#         <a href="index.html"><img src="logo1.png" alt="logo1.png" width="200" height="20"></a>
#         <a href="about.html">About</a>
#         <a href="contactus.html">Contact Us</a>
#         <a href="bs-demo-1.html">bs demo 1</a>
#         <a href="bs-demo-2.html">bs demo 2</a>
#     </nav>
#     <p></p>
#
#     <header>
#         <h1 class="bg-primary text-white text-center">Bootstrp demo 2- responsive in all devices</h1>
#     </header>
#
#     <main>
#         <section>
#             <div>
#                 <p class="text-center">
#                     Introduciton to bootstrap - center page
#                 </p>
#                 <div class="container">
#                     <p>
#                         container content - default - add, extra space to left and right
#                     </p>
#                     <p>
#                         center left, righ align content
#                     </p>
#                 </div>
#                 <div class="container-fluid">
#                     <p>
#                         container-fluid content - default stretched to 100% of screen
#                     </p>
#                     <p>
#                         center left, righ align content
#                     </p>
#                 </div>
#                 <p class="text-info">
#                     Text font, formatting
#                 </p>
#                 <div>
#                     <p class="bg-info">paragraph 1</p>
#                     <p class="text-success">paragraph 2</p>
#                     <p>paragraph 3</p>
#                     <p>paragraph 4</p>
#                 </div>
#                 <p>bootstrap grrid system</p>
#                 <div>
#
#                 </div>
#                 <p>
#                     Item List
#                 </p>
#                 <ul>
#                     <li>item 1</li>
#                     <li>item 2</li>
#                     <li>item 3</li>
#                 </ul>
#                 <p></p>
#                 <span>span example 1</span>
#                 <p></p>
#                 <p>font style, color example</p>
#                 <p></p>
#             </div>
#         </section>
#     </main>
#
#     <p></p>
#
#     <footer>
#         footer @ 2025
#     </footer>
# </body>
# </html>

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>About</title>
# </head>
# <body>
#
#     <!-- navigation menu -->
#     <nav>
#         <a href="index.html"><img src="logo1.png" alt="logo1.png" width="200" height="20"></a>
#         <a href="about.html">About</a>
#         <a href="contactus.html">Contact Us</a>
#         <a href="bs-demo-1.html">bs demo 1</a>
#         <a href="bs-demo-2.html">bs demo 2</a>
#         <a href="bs-demo-3.html">bs demo 3</a>
#     </nav>
#     <p></p>
#
#     <!-- main -->
#     <main>
#         <!-- section -->
#         <section>
#              <!-- heaader -->
#               <header>
#                  <h2>About Page</h2>
#               </header>
#
#               <div>
#                 <p>About webiste </p>
#               </div>
#          </section>
#          <p></p>
#
#          <div>
#             Lorem ipsum sample text
#          </div>
#          <p></p>
#          <div>
#             Lorem ipsum dolor sit amet consectetur adipisicing elit. Porro enim exercitationem numquam excepturi molestias quis qui sequi libero consequatur laborum ullam totam, perferendis officia blanditiis incidunt sapiente voluptates illo. Excepturi?
#          </div>
#          <p></p>
#          <div>
#             Lorem ipsum dolor sit amet consectetur adipisicing elit. Natus, iusto.
#          </div>
#          <p></p>
#         <!-- foter -->
#         <footer>
#
#         </footer>
#     </main>
#
# </body>
# </html>

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Contact Us</title>
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/bootstrap.min.css" rel="stylesheet">
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/js/bootstrap.bundle.min.js"></script>
# </head>
# <body>
#
#      <!-- navigation menu -->
#      <nav>
#         <a href="index.html"><img src="logo1.png" alt="logo1.png" width="200" height="20"></a>
#         <a href="about.html">About</a>
#         <a href="contactus.html">Contact Us</a>
#         <a href="bs-demo-1.html">bs demo 1</a>
#         <a href="bs-demo-2.html">bs demo 2</a>
#         <a href="bs-demo-3.html">bs demo 3</a>
#     </nav>
#     <p></p>
#
#     <!-- main -->
#     <main class="container">
#         <!-- section -->
#         <section>
#              <!-- heaader -->
#               <header>
#                  <h2>Contact Us</h2>
#               </header>
#
#               <div>
#                 <!--
#                 action = server url to sedn data to
#                 method = how to send the form data, get or post
#                  - get - send form data in browser address bar , data size limit of 256k
#                  - default = post - send form data in memory , unlimited data size
#                 -->
#                 <form action="/" method="post">
#                     <span>* &nbsp; first name:</span> <input type="text" placeholder="*first name required" maxlength="25" required> <br>
#                     <label>last name:</label> <input type="text"  maxlength="25"> <br>
#                     <label>* &nbsp; email:</label> <input type="email" placeholder="*email required"  maxlength="100" required> <br>
#                     <label>* &nbsp; comment: </label> <br>
#                     <textarea cols="30" rows="10" placeholder="*comment required"  maxlength="150" required></textarea>
#                     <p></p>
#                     <button class="btn btn-primary">submit</button>
#                 </form>
#               </div>
#
#          </section>
#          <p></p>
#
#         <!-- foter -->
#         <footer>
#
#         </footer>
#     </main>
#
# </body>
# </html>

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Bootstrap demo page 3</title>
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/bootstrap.min.css" rel="stylesheet">
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/js/bootstrap.bundle.min.js"></script>
#     <link rel="stylesheet" href="css/custom-bootstrap-1.css">
# </head>
# <body>
#     <nav>
#         <a href="index.html"><img src="logo1.png" alt="logo1.png" width="200" height="20"></a>
#         <a href="about.html">About</a>
#         <a href="contactus.html">Contact Us</a>
#         <a href="bs-demo-1.html">bs demo 1</a>
#         <a href="bs-demo-2.html">bs demo 2</a>
#         <a href="bs-demo-3.html">bs demo 3</a>
#     </nav>
#     <p></p>
#
#     <nav class="navbar navbar-expand-sm bg-info navbar-dark">
#         <div class="container-fluid">
#           <a class="navbar-brand" href="index.html">Logo</a>
#           <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#collapsibleNavbar">
#             <span class="navbar-toggler-icon"></span>
#           </button>
#           <div class="collapse navbar-collapse" id="collapsibleNavbar">
#             <ul class="navbar-nav">
#               <li class="nav-item">
#                 <a class="nav-link" href="about.html">About</a>
#               </li>
#               <li class="nav-item">
#                 <a class="nav-link" href="#">Link</a>
#               </li>
#               <li class="nav-item">
#                 <a class="nav-link" href="#">Link</a>
#               </li>
#             </ul>
#           </div>
#         </div>
#       </nav>
#
#     <p></p>
#
#     <header class="container-fluid">
#         <h1>Bootstrap demo page 3 - container, container-fluid</h1>
#     </header>
#
#     <p></p>
#
#     <main class="container">
#
#         <div>
#             <p>bootstrap grid demo 1</p>
#         </div>
#
#         <div class="container">
#             <div class="row">
#                 <div class="col-sm-4">col1</div>
#                 <div class="col-sm-4">col2</div>
#                 <div class="col-sm-4">col3</div>
#             </div>
#             <p></p>
#             <div class="row">
#                 <div class="col-sm-6">col1</div>
#                 <div class="col-sm-6">col2</div>
#             </div>
#             <p></p>
#             <div class="row">
#                 <div class="col-sm-8">col1</div>
#                 <div class="col-sm-2">col2</div>
#                 <div class="col-sm-4">col3</div>
#             </div>
#         </div>
#
#         <p></p>
#
#         <p>Item list</p>
#         <ul class="list-group">
#             <li class="list-group-item">item 1</li>
#             <li class="list-group-item">item 2</li>
#             <li class="list-group-item">item 3</li>
#           </ul>
#         <p></p>
#         <p>
#             tex formatting, fonts, margin, padding, alignment: cernter, left, right, top, bottom
#         </p>
#         <p>
#             text bg-color, text-color, text-alignment
#         </p>
#         <p>
#             responsive in all devices
#         </p>
#         <p>
#             bootstrap icon, menu icons
#         </p>
#     </main>
#
#     <p></p>
#     <footer>
#         footer @ 2025
#     </footer>
# </body>
# </html>
