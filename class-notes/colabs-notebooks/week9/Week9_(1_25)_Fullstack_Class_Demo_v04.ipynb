# %% [markdown]
# # Week 7-8-9 topic summary
#
# ## Class weekly demos
# - https://github.com/dgilbert-quickstart/weekly-class-demos.git
#
# ### Data structures and algorithm theory
#   - course pdf document reference and examples
#   - modern javascript es5+
#   - array, list, set, map/dictornary, tuple, queue, stack, other
#   - data structure fundamentals
#   - demo data structures crud, loop
#   - demo object oriented programming
#
# ### JavaScript Objects and OOP Programming with JavaScript
#   - https://www.w3schools.com/Js/js_classes.asp
#   - modern javascript es5+
#   - code reuse
#     - es4 function objects
#     - es6+ oop
#     - constructor,  inheritance, encapsolation, polymorphism
#   - functional programming, grouped funcrtions , modular programming
#     - map, reduce, foreach, other
#
# ##Web development workflow summary
# - **frontend** website development
#   - 1. **vs.code** - create website html/css/js
#     - custom or manual web development
#     - preview website using live server
#     - see: step-by-step notes provides
#   - 2. **nodejs**  - create website html/css/js
#     - custom or manual web development
#     - npm init -y
#     - package.json
#     - .gitignore
#     - install/uninstall npm packages
#     - see: step-by-step notes provides
#   - 3. **react** frontend website html/css/js
#     - create react application using
#       - create-react-app
#       - yarn
#       - vite
#       - other
#     - react generate html/css/js
#     - see: step-by-step notes provides
#   - 4. **backend** nodejs webiste, api, programs, development
#     - npm init -y
#     - package.json
#     - .gitignore
#     - install/uninstall npm packages
#     - nodejs backend code run on the machine/server in the background
#     - or can create nodjs websites or nodejs api or batch programs
#     - backend programs does not require a web screen
#     - run backend javascript code using **node** program
#     - see: step-by-step notes provides
#
# ### Introduction to Nodejs
#   - https://www.w3schools.com/nodejs/
#   - https://nodejs.org/en/download
#   - nodejs,js program/websever us to build frontend and backend js applications
#   - nodejs is also a js build tools used to generate js code
#   - installing nodejs
#   - Nodejs fundamentals
#   - npm package manager
#     - create a nodejs project
#     - install/un-install javascript libraries
#   - nodejs backend server side demo app
#   - nodejs frontend client side demo app
#
# # npm package website
# - javascript librraies created by other developers
# - https://www.npmjs.com/search?q=repository
#
# ### Introduction to React
#   - https://www.w3schools.com/react/default.asp
#   - SPA - Single page application ie: React, Angular, Vue
#   - Rapidly create a large dynamic websites/webpages
#   - ie: ecommerce, social media, spotify, shopify, facebook,gaming,other
#   - react uses core javascript and moders javascript in react
#   - react uses jsx - modified version of html
#   - react uses virtual DOM in memory copy of browser DOM
#   - virtual DOM is used to sync in-momery DOM with browser DOM
#   ie: for fast reactive websites
#   - react generates dynamic DOM
#   - react generates backword compatable browser javascript code
#   - install nodejs create-react-app program
#   - create a nodejs react project
#     - install/un-install react javascript libraries
#   - React fundamentals
#   - components
#   - react router
#     - navagation menu
#   - react hooks
#   - data structures crud, loop
#   - contact us
#   - deploy react app to github pages
#
# ### Deploy react app to github pages
#   - demo deploy a react app to github pages
#
# ### Demo Project 3: Task Management Web App
#   - modern javascript es5+
#   - React fundamentals
#     - react router
#       - navagation menu
#   - react hooks
#   - task list management
#   - contact us validation
#   - nodejs, npm
#   - deploy react app to github pages
#   - git
#
# ## Principles of Software Engineering II: System Design

# %% [markdown]
# #week 4-5 top summary
#   - https://www.w3schools.com/js/
#   - javascript programming intro
#     - es1-es6+
#       - Js 1..4 - 1997-2008
#       - Es5 - 2009+
#       - Es6 - 2015+ 2020
#     - variables, if, while
#     - array
#     - object
#     - json data
#     - other
#   - dynamic programming
#   - static websites , static web pages
#     - dynamic websites ie: dynamic web pages
#     - pre- react javascript dynamic websites
#     -  event:mouse, keyboard, page, timer, DOM-Document Object-Model, code actions
#     - event attribute js script reference
#     - page script js refence
#     - external file js script refence
#   - demo dynamic web applications
#     - es1-4,es5,es6+
#     - inteactive web applications
#     - generating html using the DOM
#     - selecting DOM elements
#     - wireframe, user stories, githubpages, git clone
#     - display date/time
#     - array introduction
#     - invoice/inventory claculator
#     - contact form validation
#     - ecommerce apps
#     - todo list app or task management
#     - shopping cart application
#     - display web data app ie: json placeholder
#     - javascript games ie: canvas, tic-tac-toe, other
#     - other
#   - deply website to github pages
#   - Json document introduction demo
#   - Query REST api introduciton demo
#   - demo project #2 web application
#   - search engine demo app
#   - giphy api
#     - https://giphy.com/
#     - Giphy api introduction demo
#   - Rest API  -  Representational State Transfer API,
#     - A way for applications to communicate with each other over the interne
#     - Retrieve and update data from other websites
#     - get, post, put, delete
#     - json data
#     - promise, async/await programming
#     - non-blocking api call promise, async/await
#   - css compiler SCSS introduction
#     - css compiler SCSS introduction  demo
#   - css media queries - responsive websites
#     - css media queries - responsive websites demo
#   - other

# %% [markdown]
# # Week (1-2) - Topic summary
#   - HTML5
#   - Nav menu
#   - layout
#   - Css
#   - Bootstrap
#   - Git, Github
#   - Github pages
#   - vs.code
#     - vs.code extensions
#   - browser devtools
#   - Software Engineer Development/Tools/Management
#   - Product Development/Tools/Management

# %% [markdown]
# #react task management app
#   - wireframe
#   - react navigation, components, hooks
#   - modern javascipt es5+
#   - data structures todo list task managemnt
#   - contact us page validation
#   - nodejs / npm
#   - deploy react app to github pages
#   - git
#
# ![image.png](data:image/png;base64,...)
#
# #contact us - wireframe
#
# <pre>
# <xmp>
# Home / Contact Us
#
# Contact Us
# -----------------
# first name: _____________
# last name: _____________
# email: _____________
# comment:
#
# [submtt] [clear]
#
#
# </xmp>
# </pre>

# %% [markdown]
# #Nodejs Demo #1
# - command line: node --version
# - nodejs version 20.x and above
#   - nodejs backend program/webserver - non-browser javascript development
#   - nodejs frontend website
#     - npm - node pacakeg manager - tool used to create a nodejs project and install/un-install javascript libraries
#     - creating a nodejs project
#     - package.json file
#     - .gitignore file
#     - node_modules
#     - installing/un install - frontend/backend development javascript libraries
#     - react uses nodejs and features mentioned

# %% [markdown]
# ## delete **node_modules** folder
# - reccomended to delete **node_modules** when completred working on a nodejs project

# %% [markdown]
# ## REACT is a nodejs fronend development library/progrm used to raplidly development and publish large or many fronend websites.
# - React or SAP - nodejs fronend tools used to generate a fronend webiste
# - other SPA (Single Page Application) - Vue, Anguler, Other
#
# ### Introduction to React
#   - https://www.w3schools.com/react/default.asp
#   - SPA - Single page application ie: React, Angular, Vue
#   - Rapidly create a large dynamic websites/webpages
#   - ie: ecommerce, social media, spotify, shopify, facebook,gaming,other
#   - react uses core javascript and moders javascript in react
#   - react uses jsx - modified version of html
#   - react uses virtual DOM in memory copy of browser DOM
#   - virtual DOM is used to sync in-momery DOM with browser DOM
#   ie: for fast reactive websites
#   - react generates dynamic DOM
#   - react generates backword compatable browser javascript code
#   - install nodejs create-react-app program
#   - create a nodejs react project
#     - install/un-install react javascript libraries
#   - React fundamentals
#   - components
#   - react router
#     - navagation menu
#   - react hooks
#   - data structures crud, loop
#   - contact us
#   - deploy react app to github pages

# %% [markdown]
# # Create a new React frontend application
#
# <pre>
# <xmp>
#
# - optional:
# - create a public repository
# - with readme file
# - clone repo
#
# </xmp>
# </pre>
#
# ### Install create react tools
#
# <pre>
# <xmp>
#
# - goto windows commandline or macos command terminal
# - from cloned folder or from root application folder
#
# [sudo] npm install create-react-app -g
# [sudo] npm install yarn -g
#
# </xmp>
# </pre>
#
# ### create new react appliciton
#
# <pre>
# <xmp>
#
# - goto windows commandline or macos command terminal
# - from cloned folder or from root application folder
#
# [sudo] create-react-app your-react-app
# [sudo] yarn create react-app demo-yarn-app-v1
# [sudo] npm create vite@latest react-demo-app-vite-v1 --temple react
#
# </xmp>
# </pre>
#
#
# ### install react npm packages and start react appliction
# - done 1 time on new react application creation or cloned react/nodejs app
#
# <pre>
# <xmp>
#
# from vs.code
# goto command terminal or the newly created react application
#
# cd your-react-app
# [sudo] npm install
#
# start react applicaiton
# [sudo] npm start
#
# ##vite
# [sudo] npm run dev
#
# access react applciton from localhost:3000
#
# stop react application
# ctrl+c
#
# </xmp>
# </pre>
#
# - building/publishing react app
#
# - [sudo] npm run build
# - [sudo] yarn run build
#
# <pre>
# <xmp>
# vs.code format html file
# windows: shift + alt + F
# macos: shift + Option + F
# </xmp>
# </pre>

# %% [markdown]
# # Create first react webpage/component/element
#   - create jsx screen from wireframe
#   - browser devtools - element, console, network
#   - root element
#   - eslint
#   - live update
#   - create functions - ie: es5 arrow funtcions
#   - log funcion names to console
#   - link functons to onClick
#     - lnkdemo1
#     - lnkdemo2
#     - btndemo1
#
# <pre>
# <xmp>
#
# React demo website v02
#
# link demo 1
# link demo 2
# [button demo 1]
#
# [divdisplay]
#
# footer @ 2025
#
# </xmp>
# </pre>

# %% [markdown]
# # create header and footer components
# - create a component from wireframe
# - create src/components folder
# - pass props/parameters to components
# - display props data in component
#   - src/components/header props title
#   - src/components/footer props title year

# %% [markdown]
# #unable to save files vs.code macos
# - https://sergi-jimenez.medium.com/vscode-does-not-allow-me-to-save-for-macos-in-2-minutes-a01af91f2515
#
# - solutions:
# - sudo /Applications/Visual\ Studio\ Code.app/Contents/MacOS/Electron
#
# - or set write access at folder
# - from vs.code and from react project
# - goto command termnal then enter the following
# - sudo chmod -R .

# %% [markdown]
# #demo react website #2
#
# <pre>
# <xmp>
#
# globall install/uninstall, done one time
#
# [sudo]npm uninstall create-react-app
# [sudo]npm uninstall yarn
#
# [sudo]npm install -g create-react-app
# [sudo]npm install -g yarn
#
# create-react-app --version
# yarn --version
#
# delete "node_modules" from react project you are not using
#
# 1. - create a public repo with readme file ie: react-demo-app-v01
# - from windows comand line or mac ternal
# - from a un-cloned or root peject folder
#
# 2- clone repo
# 3- create react app in cloned repo
#   cd into cloned folder
#
#   [sudo]create-react-app react-demo-app-v01
#   [sudo] yarn create react-app demo-yarn-app-v1
#   [sudo] npm create vite@latest react-demo-app-vite-v1 --temple react
#
# 4. from vs.code goto cloned folder
# goto newly created react app
# select app.js
# from command terminal run the following commands
#
# insall nmp packages
# = done one time
# [sudo] npm install
#
# start react project
# [sudo] npm start
#
# optional: stop react app = ctr+c
#
# note:
# can acces react app from localhost:3000
#
# 5. update react code to github repo
#   from cloned folder and not from react folder
#   goto newly created react app
#   select app.js
#   add the following code inside <header> tag:
#   <p>live update demo 1...</p>
#   preview update in browse
#
# 6. open new command terminal from clone repository and not from react app
#   then enter git command to update git hub
#   git add, commit, push
#   note: able to see mondifications in github
#   note: repeat steps for other project updates
#
# 7- modify react applicaiton and updaet githu repo
#
# 7.1. modify App.js the following
#
# function App() {
#   return (
#     <>
#           <p>Demo react app v1.0</p>
#           <div>
#             <a href="#">useRef demo 1</a><p></p>
#             <a href="#">useState demo 1</a><p></p>
#           </div>
#           <div>
#             [displa info]
#           </div>
#           <p>Footer @ 2025</p>
#     </>
#   );
# }
#
# export default App;
#
# note: preview update in browser
#
# 7.2 from cloned repo and not the react app
#   update github
#   git add, commit, push
#
# </xmp>
# </pre>
#
# ### react demo wireframe
# <pre>
# React Demo App v01
#
# useref demo 1
# usestate demo 1
#
# footer @ 2025
#
# </pre>

# %% [markdown]
# ##Step by Step - Create React App and Add Navigation
#
# <pre>
# <xmp>
#
#
# demo create react app and react github repo and react navigation menu
#
# globall install , done one time
#
# [sudo]npm uninstall create-react-app -g
# [sudo]npm uninstall yarn -g
#
# [sudo] npm install -g create-react-app
# [sudo] npm install -g yarn
#
# delete "node_modules" from react project you are not using
#
# create-react-app --version
# yarn --version
#
# ############################################
#
# demo react website #2
#
# 1. - create a public repo with readme file ie: react-demo-app-v01
#
# - from windows comand line or mac ternal
#   from a un-cloned or root peject folder
#
# 2- clone repo
#  git clone
#
# 3- create react app in cloned repo
#   cd into cloned folder
#
#   [sudo]create-react-app react-demo-app-v01
#   [sudo]yarn create react-app demo-yarn-app-v1
#   [sudo]npm create vite@latest react-demo-app-vite-v1 --temple react
#
# 4. from vs.code goto cloned folder
# goto newly created react app
# select app.js
# from command terminal run the following commands
#
# insall nmp packages
# = done one time
# [sudo] npm install
#
# start react project
# [sudo] npm start
#
# optional: stop react app = ctr+c
#
# note:
# can acces react app from localhost:3000
#
# 5. update react code to github repo
#   from cloned folder and not from react folder
#   goto newly created react app
#   select app.js
#   add the following code inside <header> tag:
#   <p>live update demo 1...</p>
#   preview update in browse
#
# 6. open new command terminal from clone repository and not from react app
#   then enter git command to update git hub
#   git add, commit, push
#   note: repeat steps for other project updates
#
# ==================================
#
# 7- modify react applicaiton and udpaet github
#
#
# 7.1. modify App.js the following
#
# function App() {
#   return (
#     <>
#           <p>Demo react app v1.0</p>
#           <div>
#             <a href="#">useRef demo 1</a><p></p>
#             <a href="#">useState demo 1</a><p></p>
#           </div>
#           <div>
#             [displa info]
#           </div>
#           <p>Footer @ 2025</p>
#     </>
#   );
# }
#
# export default App;
#
# note: preview update in browser
#
# 7.2 from cloned repo and not the react app
#   update github
#   git add, commit, push
#
#
# ############################################
#
# react demo wireframe
#
# React Demo App v01
#
# useref demo 1
# usestate demo 1
#
# footer @ 2025
#
# ############################################
#
# 8- modify react applicaiton and update github
#   - create functions to test useref and usestate links
#   - add links to test useref and useState
#
# 8.1. modify App.js the following
#
# function App() {
#
#   function lnkuserefdemo1(){
#    let msgText = "# app::lnkuserefdemo1"
#    console.log(msgText)
#   }
#
#
#   const lnkusestatedemo1 = () => {
#    let msgText = "# app::lnkusestatedemo1"
#    console.log(msgText)
#   }
#
#   return (
#     <>
#           <p>Demo react app v1.0</p>
#           <div>
#             <a href="#" onClick={lnkuserefdemo1}>useRef demo 1</a><p></p>
#             <a href="#" onClick={lnkusestatedemo1}>useState demo 1</a><p></p>
#           </div>
#           <div>
#             [displa info]
#           </div>
#           <p>Footer @ 2025</p>
#     </>
#   );
# }
#
# export default App;
#
# note: preview update in browser
#
# 8.2 from cloned repo and not the react app
#   goto command terminal
#   update github
#   git add, commit, push
#
# #############################################
#
# 9- modify react applicaiton and create react components
#   - home
#
# 9.1 create Home.js component with the following code
# src\components\Home.js
# ---------------------------------------
#
# function Home() {
#
#   function lnkuserefdemo1(){
#    let msgText = "# app::lnkuserefdemo1"
#    console.log(msgText)
#   }
#
#
#   const lnkusestatedemo1 = () => {
#    let msgText = "# app::lnkusestatedemo1"
#    console.log(msgText)
#   }
#
#   return (
#     <>
#           <p>Demo react app v1.0</p>
#           <div>
#             <a href="#" onClick={lnkuserefdemo1}>useRef demo 1</a><p></p>
#             <a href="#" onClick={lnkusestatedemo1}>useState demo 1</a><p></p>
#           </div>
#           <div>
#             [displa info]
#           </div>
#           <p>Footer @ 2025</p>
#     </>
#   );
# }
#
# export default Home;
#
# note: preview update in browser
#
# 9.2 from cloned repo and not the react app
#   goto command terminal
#   update github
#   git add, commit, push
#
# #############################################
#
# 10- update App.js to include home component
#
# 10.1 App.js to the following
#
# import Home from './components/Home'
#
# function App() {
#
#
#   return (
#     <>
#        <Home/>
#     </>
#   );
# }
#
# export default App;
#
# note: preview update in browser
#
# 10.2 from cloned repo and not the react app
#   update github
#   git add, commit, push
#
#
# ############################################
#
# 11- test building/publishing react app
#
# from react app, goto command terminal and run the following command
#
#     - [sudo] npm run build
#     - [sudo] yarn build
#
# ############################################
#
# 12. install react router navigation
# - done 1 time
# from react app app, goto command terminal and enter the following
#
# [sudo] npm install -D react-router-dom
#
# note: react router dom is now added to pacakge.json
# note: -D - add library only for development
# note: react will generate html url path
#
# ############################################
#
# 13. Add navigation menu to react app
# update App.js to the following
#
# //import {BrowserRouter, Routes, Route} from "react-router-dom"
# //-- hashrouter - used with GitHub pages
# import {HashRouter, Routes, Route} from "react-router-dom"
# import Home from './components/Home'
#
# function App() {
#   return (
#     <>
#      <HashRouter>
#       <Routes>
#         <Route path="/" element={<Home/>}/>
#       </Routes>
#      </HashRouter>
#     </>
#   );
# }
#
# export default App;
#
# note: preview update in browser
#
# 13.2 from cloned repo and not the react app
#   update github
#   git add, commit, push
#
#
# #############################################
#
# 14- create about components
#
# 14.1 create Home.js component with the following code
# src\components\About.js
# ---------------------------------------
# import { Link } from "react-router-dom";
#
# function About()
# {
#     return (
#         <>
#             <p>About Page</p>
#             <p></p>
#             <Link to="/">Home</Link>
#         </>
#     )
# }
#
# export default About;
#
# note: preview update in browser
#
# 14.2 from cloned repo and not the react app
#   update github
#   git add, commit, push
#
# #############################################
#
# 15 add About component to react app
#
# 15.1 update App.js to the following
#
# //import {BrowserRouter, Routes, Route} from "react-router-dom"
# import {HashRouter, Routes, Route} from "react-router-dom"
# import Home from './components/Home'
# import About from './components/About'
#
# function App() {
#   return (
#     <HashRouter>
#       <Routes>
#         <Route path="/" element={<Home/>}/>
#         <Route path="/about" element={<About/>}/>
#       </Routes>
#     </HashRouter>
#   );
# }
#
# export default App;
#
# note: preview update in browser
#
# 15.2 from cloned repo and not the react app
#   update github
#   git add, commit, push
#
# ############################################
#
# 16. create navigation menu component
#
# 16.1 create NavBar.js component with the following code
# src\components\NavBar.js
# ---------------------------------------
#
# import { Link } from "react-router-dom";
#
# function NavBar() {
#     return (
#       <>
#           <nav>
#             <Link to="/">Home</Link> {" | "}
#             <Link to="/about">About</Link>
#           </nav>
#       </>
#     );
# }
#
# export default NavBar;
#
# note: preview update in browser
#
# 16.2 from cloned repo and not the react app
#   update github
#   git add, commit, push
#
# ############################################
#
# 17. add navigation component to app navigation
#
# 17.1 update App.js to the following
#
# import {HashRouter, Routes, Route} from "react-router-dom"
# import NavBar from './components/NavBar'
# import Home from './components/Home'
# import About from './components/About'
#
# function App() {
#   return (
#     <HashRouter>
#      <NavBar/>
#       <Routes>
#         <Route path="/" element={<Home/>}/>
#         <Route path="/about" element={<About/>}/>
#       </Routes>
#     </HashRouter>
#   );
# }
#
# export default App;
#
# note: preview update in browser
#
# 17.2 from cloned repo and not the react app
#   update github
#   git add, commit, push
#
# ############################################
#
# create test page/components add test pages
# to navigation component
# component/pages/page1
# component/pages/page2
# components/contactus
#
# ########################################
#
# create Header, Footer component
#   - add props to header, footer
#
# #############################################
#
# modify Home component to include
#   - header, footer
#   - add props to header, footer
#
#
# </xmp>
# </pre>

# %% [markdown]
# #Demo react app 3.0
#
# - 1. create a new public react repo
# - 2. clone repo
# - 3. create react app - ie: command terminal
# - 4. npm install react libraries - ie: vs.code
# - 5. start react app  - ie: vs.code
# - 6. enter demo text, test live update ie: vs.code
# - 7. update github ie: vs.code
# - 8. update app.js to wire frame
# - 9. update github ie: vs.code
# - 10. add src/Home.js
# - 11. update App.js to add Home.js
# - 12. update github ie: vs.code
# - 13. create linkdemo1 and linkdemo2 functions in App.js
# - 14. link functions to anchor tags
# - 15. update github ie: vs.code
# - 16. install reacr router dom - ie: vs.code
# - 17. update App.js with HasbRouter and Home route
# - 18. add src/components/About.js
# - 19. update App.js to include About route
# - 20. update github ie: vs.code
# - 21. create src/components/NavBar.js
# - 22. update App.js to add NavBar
# - 23. update github ie: vs.code
# - note: can add other pages ie: Page1.js
# - note: can add link to other pages ie: <Link to="/">Home</Link>
# -
#
# #demo wireframe
#
# <pre>
# <xmp>
# Home | About
#
# Demo react app v3.0
#
# useRef demo 1
# useState demo 1
#
# [displa info]
#
# Footer @ 2025
#
# </xmp>
# </pre>

# %% [markdown]
# #Deply a react App and vite react app to Github Page
#
# <pre>
# <xmp>
#
# 1. install gh-pages
#   from react app goto command terminal
#   enter the command
#
#   [sudo] npm install -D gh-pages
#
# 2. In the package.json file add these lines before "start": "react-scripts start"
#
# "predeploy": "npm run build",
# "deploy": "gh-pages -d build",
#
# example after add:
# --------------------
# "scripts": {
#     "predeploy": "npm run build",
#     "deploy": "gh-pages -d build",
#     "start": "react-scripts start",
#     "build": "react-scripts build",
#     "test": "react-scripts test",
#     "eject": "react-scripts eject"
#   },
#
# 3. In the package.json file add this line after "name"
# "homepage": "https://YOUR-GITHUB-USER-NAME.github.io/YOUR-REACT-REPO-NAME",
#
# example:
# "homepage": "https://dgilbert-quickstart.github.io/react-demo-github-app-1",
#
# 4. deploy react app
#   from react app goto command terminal
#   enter the command
#
#  [sudo] npm run deploy
#
# you can access your react app at the base url specified
#
# example:
# https://dgilbert-quickstart.github.io/react-demo-github-app-1
#
# note:
# a gh-pages branch in your repository and your app is deployed
# (you can check it under Settings -> Pages )
#
# ----------------------------------------------------
# Deploy Vite React App to Githu Pages
# ----------------------------------------------------
# 1. install gh-pages
#   from react app goto command terminal
#   enter the command
#   [sudo] npm install -D gh-pages
#
# 2. In the package.json file add these lines before "build": "vite build",
# "predeploy": "npm run build",
#
# from:
#
# "scripts": {
# "deploy": "gh-pages -d dist",
# }
#
# to:
#
# "scripts": {
#   "deploy": "gh-pages -d dist -r https://github.com/username/repository.git"
# }
#
#
# 3. In the vite.config.js file add this line before plugins: [react()],
# base: "https://YOUR-GITHUB-USER-NAME.github.io/YOUR-REACT-REPO-NAME",
#
# example:
# base: "https://dgilbert-quickstart.github.io/react-demo-github-app-1",
#
# 4. deploy react app
#   from react app goto command terminal
#   enter the command
#
#  [sudo] npm run deploy
#
# you can access your react app at the base url specified
#
# example:
# https://dgilbert-quickstart.github.io/react-demo-github-app-1
#
# note:
# a gh-pages branch in your repository and your app is deployed
# (you can check it under Settings -> Pages )
#
# #################################################
#
# ------------------
# vite error
# - windows
# - macos
# ------------------
#
# @vite gh-pages deployement error
# @vite deploy react app to github pages
#
# Error: Failed to get remote.origin.url (task must either be run in a git repository with a
# configured origin remote or must be configured with the "repo" option).
#
# at D:\Class Demos\Weekly Demos\Week 9\React Project\classdemos\classdemoreact\Demo-1\node_modules\gh-pages\lib\git.js:214:13
#
# at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#
# ###########################################
#
# solution:
# --------
#
# from:
#
# "scripts": {
# "deploy": "gh-pages -d dist",
# }
#
# to:
#
# "scripts": {
#   "deploy": "gh-pages -d dist -r https://github.com/username/repository.git"
# }
#
#
# </xmp>
# </pre>

# %% [markdown]
# # demo course project #3
# - https://create-react-app.dev/docs/getting-started/
#
# - react router dom
# - contact us
# - todolist app
# - add css style
# - deploy react app to github pages
