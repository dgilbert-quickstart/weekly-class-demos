# %% [markdown]
# # Week 7-8-9 topic summary
#
# ## Class weekly demos
# - https://github.com/dgilbert-quickstart/weekly-class-demos.git
#
# ### Data structures and algorithm theory
#   - course pdf document reference and examples
#   - modern javascript es5+
#   - array, list, set, map/dictornary, tuple, queue, stack, other
#   - data structure fundamentals
#   - demo data structures crud, loop
#   - demo object oriented programming
#
# ### JavaScript Objects and OOP Programming with JavaScript
#   - https://www.w3schools.com/Js/js_classes.asp
#   - modern javascript es5+
#   - code reuse
#     - es4 function objects
#     - es6+ oop
#     - constructor,  inheritance, encapsolation, polymorphism
#   - functional programming, grouped funcrtions , modular programming
#     - map, reduce, foreach, other
#
# ##Web development workflow summary
# - **frontend** website development
#   - 1. **vs.code** - create website html/css/js
#     - custom or manual web development
#     - preview website using live server
#     - see: step-by-step notes provides
#   - 2. **nodejs**  - create website html/css/js
#     - custom or manual web development
#     - npm init -y
#     - package.json
#     - .gitignore
#     - install/uninstall npm packages
#     - see: step-by-step notes provides
#   - 3. **react** frontend website html/css/js
#     - create react application using
#       - create-react-app
#       - yarn
#       - vite
#       - other
#     - react generate html/css/js
#     - see: step-by-step notes provides
#   - 4. **backend** nodejs webiste, api, programs, development
#     - npm init -y
#     - package.json
#     - .gitignore
#     - install/uninstall npm packages
#     - nodejs backend code run on the machine/server in the background
#     - or can create nodjs websites or nodejs api or batch programs
#     - backend programs does not require a web screen
#     - run backend javascript code using **node** program
#     - see: step-by-step notes provides
#
# ### Introduction to Nodejs
#   - https://www.w3schools.com/nodejs/
#   - https://nodejs.org/en/download
#   - nodejs,js program/websever us to build frontend and backend js applications
#   - nodejs is also a js build tools used to generate js code
#   - installing nodejs
#   - Nodejs fundamentals
#   - npm package manager
#     - create a nodejs project
#     - install/un-install javascript libraries
#   - nodejs backend server side demo app
#   - nodejs frontend client side demo app
#
# # npm package website
# - javascript librraies created by other developers
# - https://www.npmjs.com/search?q=repository
#
# ### Introduction to React
#   - https://www.w3schools.com/react/default.asp
#   - SPA - Single page application ie: React, Angular, Vue
#   - Rapidly create a large dynamic websites/webpages
#   - ie: ecommerce, social media, spotify, shopify, facebook,gaming,other
#   - react uses core javascript and moders javascript in react
#   - react uses jsx - modified version of html
#   - react uses virtual DOM in memory copy of browser DOM
#   - virtual DOM is used to sync in-momery DOM with browser DOM
#   ie: for fast reactive websites
#   - react generates dynamic DOM
#   - react generates backword compatable browser javascript code
#   - install nodejs create-react-app program
#   - create a nodejs react project
#     - install/un-install react javascript libraries
#   - React fundamentals
#   - components
#   - react router
#     - navagation menu
#   - react hooks
#   - data structures crud, loop
#   - contact us
#   - deploy react app to github pages
#
# ### Deploy react app to github pages
#   - demo deploy a react app to github pages
#
# ### Demo Project 3: Task Management Web App
#   - modern javascript es5+
#   - React fundamentals
#     - react router
#       - navagation menu
#   - react hooks
#   - task list management
#   - contact us validation
#   - nodejs, npm
#   - deploy react app to github pages
#   - git
#
# ## Principles of Software Engineering II: System Design

# %% [markdown]
# #week 4-5 top summary
#   - https://www.w3schools.com/js/
#   - javascript programming intro
#     - es1-es6+
#       - Js 1..4 - 1997-2008
#       - Es5 - 2009+
#       - Es6 - 2015+ 2020
#     - variables, if, while
#     - array
#     - object
#     - json data
#     - other
#   - dynamic programming
#   - static websites , static web pages
#     - dynamic websites ie: dynamic web pages
#     - pre- react javascript dynamic websites
#     -  event:mouse, keyboard, page, timer, DOM-Document Object-Model, code actions
#     - event attribute js script reference
#     - page script js refence
#     - external file js script refence
#   - demo dynamic web applications
#     - es1-4,es5,es6+
#     - inteactive web applications
#     - generating html using the DOM
#     - selecting DOM elements
#     - wireframe, user stories, githubpages, git clone
#     - display date/time
#     - array introduction
#     - invoice/inventory claculator
#     - contact form validation
#     - ecommerce apps
#     - todo list app or task management
#     - shopping cart application
#     - display web data app ie: json placeholder
#     - javascript games ie: canvas, tic-tac-toe, other
#     - other
#   - deply website to github pages
#   - Json document introduction demo
#   - Query REST api introduciton demo
#   - demo project #2 web application
#   - search engine demo app
#   - giphy api
#     - https://giphy.com/
#     - Giphy api introduction demo
#   - Rest API  -  Representational State Transfer API,
#     - A way for applications to communicate with each other over the interne
#     - Retrieve and update data from other websites
#     - get, post, put, delete
#     - json data
#     - promise, async/await programming
#     - non-blocking api call promise, async/await
#   - css compiler SCSS introduction
#     - css compiler SCSS introduction  demo
#   - css media queries - responsive websites
#     - css media queries - responsive websites demo
#   - other

# %% [markdown]
# # Week (1-2) - Topic summary
#   - HTML5
#   - Nav menu
#   - layout
#   - Css
#   - Bootstrap
#   - Git, Github
#   - Github pages
#   - vs.code
#     - vs.code extensions
#   - browser devtools
#   - Software Engineer Development/Tools/Management
#   - Product Development/Tools/Management

# %% [markdown]
# #react task management app
#   - wireframe
#   - react navigation, components, hooks
#   - modern javascipt es5+
#   - data structures todo list task managemnt
#   - contact us page validation
#   - nodejs / npm
#   - deploy react app to github pages
#   - git
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## create-react-app -vs- vite/js
#  - used to build the react frontend application
#  - generate frontend website (html/css/js)
#
# <pre>
# <xmp>
# create nodejs application
# - backend application
# - frontend website
#    - html/css/js
#    - react frontend development tools
# 	- create-react-app *newly optimized*
#         - vite/js - create react app - *optimized*
#    - react frontend (build frontend)
#       - generate fronend website (html/css/js)
#
# </xmp>
# </pre>

# %% [markdown]
# #Nodejs Demo #1
# - command line: node --version
# - nodejs version 20.x and above
#   - nodejs backend program/webserver - non-browser javascript development
#   - nodejs frontend website
#     - npm - node pacakeg manager - tool used to create a nodejs project and install/un-install javascript libraries
#     - creating a nodejs project
#     - package.json file
#     - .gitignore file
#     - node_modules
#     - installing/un install - frontend/backend development javascript libraries
#     - react uses nodejs and features mentioned

# %% [markdown]
# ## backend nodejs program or webserver demo 1
# - backend code run on the server/computer ie: background
# - can create webserver ie: api webserver
# - can create frontend website - ie: html, css, js
#
# - npm - node pacakeg maneger
# - creating a nodejs project
# - package.json file
# - .gitignore file
# - installing/un install - backend development javascript libraries
# - node_modules
# - react uses nodejs and features mentioned
#
# <pre>
# <xmp>
# 1. create a backend webs server folder example:
# note: same folder structure that react uses
# week8\nodejs-demos\nodejs-backend-webserver-1\scr
#
# 2. initialize a nodejs project
# note: this step is done 1 time for each priject
# note: of in ...\src
# enter cd .. to go back 1 folder level
#
# cd week8\nodejs-demos\nodejs-backend-webserver-1
# npm init
#
# or
#
# npm init -y
# note: skip prompt
#
# note:
# answer project prompts
# keep the defaults
# package name: (nodejs-backend-webserver-1)
# version: (1.0.0)
# description:
# entry point: (index.js)
# test command:
# git repository:
# keywords:
# author:
# license: (ISC)
# Is this OK? (yes)
#
# -----------------------------------
# example package.json file
# -----------------------------------
# {
#   "name": "nodejs-backend-webserver-1",
#   "version": "1.0.0",
#   "main": "index.js",
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1"
#   },
#   "author": "",
#   "license": "ISC",
#   "description": ""
# }
#
#
# 3. create index.js file src filder
# week8\nodejs-demos\nodejs-backend-webserver-1\scr\index.js
#
# 4. add code to index.js file
#
#
# //any valid js code
# //non browser javascript program
#
# console.log(`# demo nodejs backend program`)
#
#
#
# 5. run code in index.js
#
# note: this step is done 1 time for each priject
# note: of in ...\src
# enter cd .. to go back 1 folder level
# note: same directory as package.json
#
# cd week8\nodejs-demos\nodejs-backend-webserver-1
# node src/index.js
#
# note:
# node command runs javascript code: ie: browser - v8 javascript engine
#
#
# </xmp>
# </pre>
#
# ##install / un-install javascript libraries
# - npm install library-name
# - npm uninstall library-name
#
# <pre>
# <xmp>
#
# 6. install/uninstall javascript libraries
#
# note: this step is done 1 time for each project
# note: of in ...\src
# enter cd .. to go back 1 folder level
# note: same directory as package.json
#
# cd week8\nodejs-demos\nodejs-backend-webserver-1
#
# npm install uuid
#
# ** macos **
# sudo npm install uuid
#
# note: nodejs creates a "node_modules" folder with libraires
#
# === uninstall library ===
#
# npm uninstall uuid
#
# note; package.json -- has refence to library
#
# "dependencies": {
#     "uuid": "^11.1.0"
#   }
#
# </xmp>
# </pre>
#
#
# ## create a .gitignore file
# - exlcude files or folder that you do not want copied/uploaded to githib repo
# - ie node_modules
#
# 7. create a .gitignore
# note: this step is done 1 time for each priject
# note: of in ...\src
# enter cd .. to go back 1 folder level
#
# cd week8\nodejs-demos\nodejs-backend-webserver-1
#
# create a .gitignore
#
# 8. enter the following code in .gitignore file
#
# node_modules
# .env
#
# note:
# when you upload files/folders to github repo
# - files/folders specified in .gitignore will not be uploaded to github repo
#
# note:
# delete "node_modules" folder and re-install npm packages
# delete "package.lock.json" - will be create by node js

# %% [markdown]
# # clone a github nodejs repository and npm all npm packages
#
# ## demo nodejs backend repository
# 1. create github nodejs backend repositoy
# - name: nodejs-backend-demo-app-v1
# - add readme.md
# - no gitigonore - manually create gitignore
#
# 2. clone repo created in step 1 in an un-cloned root folder
# - git clone
#
# 3. create nodejs backend code
# - initialize nodejs project ie: nmp init -y
# - add gitignore and add code
#   node_modules
#   .env
# - npm install uuid
#
# 4. create src/program.js and add the following code
#
# console.log("nodejs backend demo app v1")
#
# 5. git add, commit and push changes to repo
# -git add
# -git commit
# -git push
#
# ## install all npm packages
# 6. - optionally: delete local cloned folder
# re-clone repository from step 2
#
# 7. re-install npm package
# - in cloned folder enter code
# - npm install
#
# - note: nodejs will install all package.json libraries
# - note: same steps to clone a nodejs or react project and install npm libraries

# %% [markdown]
# ## delete **node_modules** folder
# - reccomended to delete **node_modules** when completred working on a nodejs project

# %% [markdown]
# # .getignore file not working in vs.code
# - git icon does not display correctly in vs.code
#
# ### download A PREVIOUS VERSION OF GIT
# - https://stackoverflow.com/questions/48331404/how-to-install-old-version-of-git-on-windows-10
#
# ## vss.code updat gitigore icon
# ## - configure .gitignore icon from vs.code in the lower right-hand bottom stry
#
# ##git verify files which are being ignored
# - git status --ignore
#
# ## other solutions
# - re-install git
# - re-install vs.code
#
# <pre>
# <xmp>
#
# #1)
#
# https://gist.github.com/pavankjadda/2bb6fbdd8786e1f57fd7bcbcc666b51d
#
# How to fix ".gitignore not working" issue?
# Sometimes git does not exclude files/folders added .gitignore especially if you had commited them before. Here is how to fix it. I am ignoring node_modules from Angular project as an example
#
# Update .gitignore with the folder/file name you want to ignore. You can use anyone of the formats mentioned below (prefer format1)
#
# ### Format1  ###
# node_modules/
# node/
#
# ### Format2  ###
# **/frontend/node_modules/**
# **/frontend/node/**
#
# Commit all the changes to git. Exclude the folder/files you don't want commit, in my case node_modules
#
# Execute the following command to clear the cache
# git rm -r --cached .
# Execute git status command and it should output node_modules and sub directories marked for deletion
# Now execute
# git add .
# git commit -m "fixed untracked files"
# That's it. Comment if you any questions.
# Update: Windows users make sure your .gitignore uses UTF-8 rather than UTF-16.
#
# #########################################
#
# #2)
#
# https://www.reddit.com/r/Unity3D/comments/elazbl/why_is_my_gitignore_not_working/?rdt=36508
#
# git rm -r --cached .
#
# rm is the remove command
#
# -r will allow recursive removal
#
# –cached will only remove files from the index. Your files will still be there.
#
# The .indicates that all files will be untracked.
#
# git add .
#
# git commit -m ".gitignore fix"
#
# Something like that.
#
# #################################################
#
# #3)
# https://kinsta.com/knowledgebase/gitignore-not-working/
#
# #4)
# https://stackoverflow.com/questions/25436312/gitignore-not-working
#
# </xmp>
# </pre>

# %% [markdown]
# ## frontend nodejs website demo 1
# - npm - node pacakeg maneger
# - creating a nodejs project
# - package.json file
# - .gitignore file
# - installing/un install - frontend development javascript libraries
# - node_modules
# - react uses nodejs and features mentioned
#
# ### npm packages install on nodejs fronend websites are mainly used in development of fron end websites.
#
# ## REACT is a nodejs fronend development library/progrm used to raplidly development and publish large or many fronend websites.
# - React or SAP - nodejs fronend tools used to generate a fronend webiste
# - other SPA (Single Page Application) - Vue, Anguler, Other
#
# ### other examlpe frontend development tools - used only in frontend development
#
# - seperate step to install or publish your frontend website to a web server
# - tools are installed 1 time
# - g = install tool globally on your computer
# - npm install http-server -g
# - npm install sass -g
#   - used to generate css , rablidly create and re-use css
#   - other tools
#
# <pre>
# <xmp>
#
# 1. create nodejs frontend website
# - initialize nodejs project ie: nmp init -y
# - add gitignore and add code
#   node_modules
#   .env
#
# 2. create fronend code
#    src/index.html
#    src/index.html
#
# 3. run nodejs fronend website
# - vs.code live server
# or
# -- globallly install a webserver to run our website locally
# npm install http-server -g
# -- done 1 time
# http-server -p 8000
#
# 4. git add, commit and push changes to repo
# -git add
# -git commit
# -git push
#
#
# </xmp>
# </pre>

# %% [markdown]
# ## REACT is a nodejs fronend development library/progrm used to raplidly development and publish large or many fronend websites.
# - React or SAP - nodejs fronend tools used to generate a fronend webiste
# - other SPA (Single Page Application) - Vue, Anguler, Other
#
# ### Introduction to React
#   - https://www.w3schools.com/react/default.asp
#   - SPA - Single page application ie: React, Angular, Vue
#   - Rapidly create a large dynamic websites/webpages
#   - ie: ecommerce, social media, spotify, shopify, facebook,gaming,other
#   - react uses core javascript and moders javascript in react
#   - react uses jsx - modified version of html
#   - react uses virtual DOM in memory copy of browser DOM
#   - virtual DOM is used to sync in-momery DOM with browser DOM
#   ie: for fast reactive websites
#   - react generates dynamic DOM
#   - react generates backword compatable browser javascript code
#   - install nodejs create-react-app program
#   - create a nodejs react project
#     - install/un-install react javascript libraries
#   - React fundamentals
#   - components
#   - react router
#     - navagation menu
#   - react hooks
#   - data structures crud, loop
#   - contact us
#   - deploy react app to github pages

# %% [markdown]
# ## globally install create-react-app
# - https://www.w3schools.com/react/default.asp
#
# - step is done 1 time
# - preferebly from window or macos command line instead of vs.code command termminal
#
# - npm install create-react-app -g
#
# or
#
# - macos
# - sudo npm install create-react-app -g
#
# ## version of create-react-app
# - create-react-app --version
#
# ## using npx to create a create react app
# ## if deprecated/warning install create-react-app
# - https://www.w3schools.com/react/default.asp
# - uninstall create-react-app
# #npx install create-react-app and create a new react project
# - goto folder to create your react app
# - npx create-react-app react-demo-app-v1
# - macos:
# - sudo npx create-react-app react-demo-app-v1
#
# ## other fronend development tools
# - vite/js
#
# ## create a new react website and run react app
# - step is done for each react app
# - preferebly from window or macos command line instead of vs.code command termminal
# - from a root development folder ie: week8/react-frontend-development
#
# - create-react-app react-demo-app-v1
#
# #from vs.code code , goto the newly create react app folder
# - from command line
# - cd react-demo-app-v1
# - npm install
# - npm start
#
# #building/publishing react app
# - npm run build

# %% [markdown]
# ## create a new react app using vite
# - from command termianl
# - goto root folder to create react app
# - npm create vite@latest react-demo-app-vite-v1 --temple react
#   - react
#   - javascript
#
# #from vs.code code , goto the newly create react app folder
# - goto command line
# - cd react-demo-app-vite-v1
# - npm install
# - npm run dev
#
# #building/publishing react app
# - npm run build

# %% [markdown]
# ## create a new react app using npm init
# -  https://create-react-app.dev/docs/getting-started/
#
# - from command terminal and not vs.code terminal
# - goto a project root folder folder
#
# - npm init react-app react-demo-init-app-v1
#
# #from vs.code code , goto the newly create react app folder
# - from command line
# - cd react-demo-init-app-v1
# - npm install
# - npm start
#
# #building/publishing react app
# - npm run build

# %% [markdown]
# ## create a new react app using yarn
# - https://create-react-app.dev/docs/getting-started/
#
# ### note: may need to install yarn
# - npm install yarn -g
#
# - from command terminal and not vs.code terminal
# - goto a project root folder folder
#
# - yarn create react-app demo-yarn-app-v1
#
# #from vs.code code , goto the newly create react app folder
# - from command line
# - cd react-demo-yarn-app-v1
# - yarn install
# - yarn start
#
# #building/publishing react app
# - yarn run build

# %% [markdown]
# ## React fronend website Demo/Workflow 1
# - react website files/folders
# - react code, features
# - build frontend/test website
# - publish/generated fronend react website

# %% [markdown]
# #React fundamental demo #1
# - https://create-react-app.dev/docs/getting-started/
#
# - re-usable react ui/ux - pages/components
# - jsx - 95% simiar to html - uncludes javascript and html
# - jax - top level/root element - components/pages -
#   - root element in jsx - only 1 container/root element
#   - do not create 2 elements in compoent/page design
#  - functions or jax functions / components / pages
#  <pre>
#   <xmp>
#     jsx - page/component
#     ie: App = react component / page
#     export function - jsx/ component/page
#     - other components can re-use app component
#
#     1 top level container elemen
#       can have multiple container element
#       top level - div
#       top <></>
#
#     <>
#     <div>
#         jax
#     </div>
#      <div>
#       <h2>Demo react app v1</h2>
#     </div>
#    </>
#
#   ===================================================
#   html/head/body - not required in componenst/pages
#   ==================================================
#   <!DOCTYPE html>
#   <html lang="en">
#   <head>
#       <meta charset="UTF-8">
#       <meta name="viewport" content="width=device-width, initial-scale=1.0">
#       <title>nodejs frontend website 2</title>
#   </head>
#   <body>
#   ...............................
#
#   jax class attribute
#   <div className="app"></div>
#
#   html
#   <div class="app"></div>
#
#   </xmp>
#  </pre>
# - modern javascrpt es5, es6+ - react creates backword compatability javascript browser code
# - components ie: jsx code snipits - pages/components
# - functions, events
# - eslint
# - props
# - useref
# - useeffect
# - usestate
# - react router DOM
# - deply react app to github pages
# - contact us - validation
# - todo list - component
# - add css style
# - publish/build react app
# - deploy react app to github pages

# %%
# %%html
#
# <!--
#   google colabs notebook or vs.code to preview jsx html code snipit
# -->
#
# <div>
#     jsx
# </div>
#   <div>
#   <h2>Demo react app v1</h2>
# </div>
# <p></p>
# <a href="#">display info demo 1</a>
# <p></p>
# <div id="divdisplay">
# </div>
# Out:
# <!--
#   google colabs notebook or vs.code to preview jsx html
# -->
#
# <div>
#     jsx
# </div>
#   <div>
#   <h2>Demo react app v1</h2>
# </div>
# <p></p>
# <a href="#">display info demo 1</a>
# <p></p>
# <div id="divdisplay">
# </div>

# %%
# %%javascript
#
# //custom react element/components/pages
# //move into seperate file
# export default function Header(props){
#     //element/component/page - return jsx
#
#     //props = properties/ attributes / data passed into the component
#     //props - can be called any name - ie: info
#     //retirve an expected property named title
#     //can pass in more than 1 property
#
#     return (
#       <>
#         <h2>{props.title}</h2>
#       </>
#     )
# }
#
# /*
#
# ERROR in [eslint]
# src\App.js
#   Line 64:10:  'Header' is not defined  react/jsx-no-undef
#
# */

# %%
# %%javascript
#
# //react element/component/page
# //move into seperate file
# const Footer = (props) =>{
#   //element/component/page - return jsx
#   return (
#     <>
#       <p>{props.title} @ {props.year} </p>
#     </>
#   )
# }
#
# export default Footer;

# %%
# %%javascript
#
# import Header from "./components/Header"
# import Footer from "./components/Footer"
#
# /*
# jsx - page/component
# ie: App = react component / page
# export function - jsx/ component/page
# - other components can re-use app component
# */
# function App() {
#
#   //-- function inside a function
#   function lnkDisplayInfo1()
#   {
#     let msgText = "# App::lnkDisplayInfo1"
#
#     //alert(msgText)
#     console.log(msgText)
#
#   }
#
#   const lnkDisplayInfo2 = () => {
#
#     let msgText = "# App::lnkDisplayInfo2"
#
#     //alert(msgText)
#     console.log(msgText)
#
#   }
#
#   //arrow function - es5+ optimized function used in functional javascript programming
#   //function is defined as a variable
#   const btnDisplayInfo2 = () =>
#   {
#
#     let msgText = "# App::btnDisplayInfo2"
#
#     //alert(msgText)
#     console.log(msgText)
#
#   }
#
#   //--- function defined before retrun (
#   //react eslint - javascrcipt compiler hints, errors, warnings
#   //Line 10:12:  'lnkDisplayInfo1' is defined but never used
#
#   return (
#     /*
#       1 top level container elemen
#       can have multiple container element
#       top level - div
#       top <></>
#     */
#
#     /*
#     props = properties - pass data to a component
#     property name = any-name=any-js-data-type
#     can pass in 1 or more properties/attributes
#     */
#    <>
#     <div>
#         <Header title="React jsx intro 1.3"/>
#     </div>
#      <div>
#       <h2>Demo react app v1</h2>
#     </div>
#     <p></p>
#     <a href="#" onClick={lnkDisplayInfo1}>display info demo 1</a>
#     <p></p>
#     <a href="#" onClick={lnkDisplayInfo2}>display info demo 2</a>
#     <p></p>
#     <button onClick={btnDisplayInfo2}>display info demo 2</button>
#     <p></p>
#     <div id="divdisplay">
#     </div>
#     <div>
#        <Footer title="footer" year="2025"></Footer>
#     </div>
#    </>
#   );
# }
#
# export default App;

# %% [markdown]
# # demo cousre project #3
# - https://create-react-app.dev/docs/getting-started/
#
# - react router dom
# - contact us
# - todolist app
# - add css style
# - deploy react app to github pages

# %% [markdown]
# # React navigation
# - react router
# - link to other pages

# %% [markdown]
# ### Deploy react app to github pages
#   - demo deploy a react app to github pages
